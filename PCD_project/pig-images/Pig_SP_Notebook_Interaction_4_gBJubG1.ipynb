# %% [markdown]
# # Pig Contact Detection System Using Convolutional Neural Networks
# **For Detection, it uses YOLOv5 with CSPDarknet as the backbone**<br>
# **For Interaction, it compares between IoU and a calibrated interaction threshold**<br>
#
# _Notebook by Joackin Santos_
#
# **Main Notebook:**
# https://colab.research.google.com/drive/1orWlSQr0xjVmVI-2SvIuBQiu3wvIgBS3?usp=sharing
#
# This is the accompanying notebook for the Pig Contact Detection System. This notebook uses the weights (*.pt) from the trained models to output the coordinates of the bounding boxes from detect.py of YOLOv5. The output is used to get the IoU (Intersection over Union) of the heads and rears in an image. This will be used to compute for interaction, based on a calibrated IoU threshold.
#
# This will use the AFBI and AUF datasets to get predictions and truth values (annotated) to evaluate the interaction method.
#
# Upon evaluation of the best threshold, the method will be extracted for single image use, to be integrated to the website application.

# %% [markdown]
# ## Setup

# %%
# for folder deletions
import shutil
shutil.rmtree('/content/datasets')

# %% [markdown]
# **Cloning Repositories**

# %%
# clone repository containing yolov5 and datasets
# rename pig-datasets repo to datasets for yolov5
# %cd /content
# !git clone -b interaction-method https://github.com/joackinsantos/YOLOv5-Modification
# !git clone https://github.com/joackinsantos/pig-datasets datasets
# Out:
# /content
# Cloning into 'YOLOv5-Modification'...
# remote: Enumerating objects: 9872, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 9872 (delta 33), reused 46 (delta 19), pack-reused 9808
# Receiving objects: 100% (9872/9872), 41.00 MiB | 25.81 MiB/s, done.
# Resolving deltas: 100% (117/117), done.
# Cloning into 'datasets'...
# remote: Enumerating objects: 27727, done.
# remote: Counting objects: 100% (767/767), done.
# remote: Compressing objects: 100% (752/752), done.
# remote: Total 27727 (delta 15), reused 767 (delta 15), pack-reused 26960
# Receiving objects: 100% (27727/27727), 884.93 MiB | 19.34 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# Updating files: 100% (29633/29633), done.

# %% [markdown]
# **Data Paths**

# %%
# resource paths
AFBI_path = '/content/datasets/interaction-set/AFBI'
AUF_path = '/content/datasets/interaction-set/AUF'
Combined_path = '/content/datasets/interaction-set/Combined'
Combined_csv_path = '/content/datasets/interaction-set/Combined.csv'
img_path = '/content/datasets/interaction-set/AFBI/AFBI001.jpg'
weight_path = '/content/YOLOv5-Modification/test-weights/'

# %%
# %ls
# Out:
# benchmarks.py    detect.py   __pycache__/      segment/        utils/
# CITATION.cff     export.py   README.md         setup.cfg       val.py
# classify/        hubconf.py  README.zh-CN.md   test-weights/
# CONTRIBUTING.md  LICENSE     requirements.txt  train.py
# data/            models/     runs/             tutorial.ipynb

# %% [markdown]
# **Detection**
# *detect.py was modified to extract bounding box properties such as:*
# - image names
# - confidence scores
# - classfication and class index
# - minX, minY, maxX, maxY <br>
#
# This is exported as the "bounding-boxes.csv" file

# %% [markdown]
# **This uses the detect.py from YOLOv5 ultralytics repository**

# %%
# %cd /content/YOLOv5-Modification
# !python detect.py --img 600 --weights {weight_path}/test.pt --source {Combined_path}
# Out:
# /content/YOLOv5-Modification
# detect: weights=['/content/YOLOv5-Modification/test-weights//test.pt'], source=/content/datasets/interaction-set/Combined, data=data/coco128.yaml, imgsz=[600, 600], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 539e7e9 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# custom_YOLOv5m summary: 212 layers, 20856975 parameters, 0 gradients
# WARNING ⚠️ --img-size [600, 600] must be multiple of max stride 32, updating to [608, 608]
# image 1/738 /content/datasets/interaction-set/Combined/AFBI001.jpg: 320x608 7 Heads, 8 Rears, 486.7ms
# image 2/738 /content/datasets/interaction-set/Combined/AFBI002.jpg: 320x608 8 Heads, 8 Rears, 480.8ms
# image 3/738 /content/datasets/interaction-set/Combined/AFBI003.jpg: 320x608 8 Heads, 8 Rears, 485.1ms
# image 4/738 /content/datasets/interaction-set/Combined/AFBI004.jpg: 320x608 9 Heads, 9 Rears, 478.7ms
# image 5/738 /content/datasets/interaction-set/Combined/AFBI005.jpg: 320x608 7 Heads, 8 Rears, 472.2ms
# image 6/738 /content/datasets/interaction-set/Combined/AFBI006.jpg: 320x608 9 Heads, 8 Rears, 484.9ms
# image 7/738 /content/datasets/interaction-set/Combined/AFBI008.jpg: 320x608 8 Heads, 9 Rears, 467.4ms
# image 8/738 /content/datasets/interaction-set/Combined/AFBI009.jpg: 320x608 9 Heads, 7 Rears, 506.3ms
# image 9/738 /content/datasets/interaction-set/Combined/AFBI010.jpg: 320x608 8 Heads, 12 Rears, 776.9ms
# image 10/738 /content/datasets/interaction-set/Combined/AFBI011.jpg: 320x608 8 Heads, 9 Rears, 776.8ms
# image 11/738 /content/datasets/interaction-set/Combined/AFBI012.jpg: 320x608 8 Heads, 9 Rears, 782.2ms
# image 12/738 /content/datasets/interaction-set/Combined/AFBI013.jpg: 320x608 8 Heads, 10 Rears, 750.9ms
# image 13/738 /content/datasets/interaction-set/Combined/AFBI014.jpg: 320x608 8 Heads, 9 Rears, 468.1ms
# image 14/738 /content/datasets/interaction-set/Combined/AFBI016.jpg: 320x608 7 Heads, 10 Rears, 479.6ms
# image 15/738 /content/datasets/interaction-set/Combined/AFBI017.jpg: 320x608 8 Heads, 9 Rears, 475.6ms
# image 16/738 /content/datasets/interaction-set/Combined/AFBI018.jpg: 320x608 9 Heads, 10 Rears, 479.4ms
# image 17/738 /content/datasets/interaction-set/Combined/AFBI019.jpg: 320x608 8 Heads, 9 Rears, 470.7ms
# image 18/738 /content/datasets/interaction-set/Combined/AFBI021.jpg: 320x608 8 Heads, 11 Rears, 476.2ms
# image 19/738 /content/datasets/interaction-set/Combined/AFBI022.jpg: 320x608 9 Heads, 9 Rears, 485.1ms
# image 20/738 /content/datasets/interaction-set/Combined/AFBI023.jpg: 320x608 10 Heads, 10 Rears, 487.7ms
# image 21/738 /content/datasets/interaction-set/Combined/AFBI024.jpg: 320x608 9 Heads, 9 Rears, 481.5ms
# image 22/738 /content/datasets/interaction-set/Combined/AFBI025.jpg: 320x608 9 Heads, 9 Rears, 480.9ms
# image 23/738 /content/datasets/interaction-set/Combined/AFBI027.jpg: 320x608 9 Heads, 9 Rears, 473.3ms
# image 24/738 /content/datasets/interaction-set/Combined/AFBI028.jpg: 320x608 8 Heads, 9 Rears, 480.9ms
# image 25/738 /content/datasets/interaction-set/Combined/AFBI029.jpg: 320x608 9 Heads, 9 Rears, 472.6ms
# image 26/738 /content/datasets/interaction-set/Combined/AFBI030.jpg: 320x608 9 Heads, 8 Rears, 477.9ms
# image 27/738 /content/datasets/interaction-set/Combined/AFBI031.jpg: 320x608 10 Heads, 9 Rears, 472.0ms
# image 28/738 /content/datasets/interaction-set/Combined/AFBI033.jpg: 320x608 10 Heads, 8 Rears, 481.0ms
# image 29/738 /content/datasets/interaction-set/Combined/AFBI034.jpg: 320x608 9 Heads, 8 Rears, 474.7ms
# image 30/738 /content/datasets/interaction-set/Combined/AFBI036.jpg: 320x608 8 Heads, 8 Rears, 485.9ms
# image 31/738 /content/datasets/interaction-set/Combined/AFBI039.jpg: 320x608 9 Heads, 10 Rears, 477.7ms
# image 32/738 /content/datasets/interaction-set/Combined/AFBI041.jpg: 320x608 8 Heads, 11 Rears, 484.7ms
# image 33/738 /content/datasets/interaction-set/Combined/AFBI042.jpg: 320x608 10 Heads, 11 Rears, 770.1ms
# image 34/738 /content/datasets/interaction-set/Combined/AFBI043.jpg: 320x608 10 Heads, 9 Rears, 796.6ms
# image 35/738 /content/datasets/interaction-set/Combined/AFBI045.jpg: 320x608 10 Heads, 10 Rears, 803.7ms
# image 36/738 /content/datasets/interaction-set/Combined/AFBI047.jpg: 320x608 9 Heads, 12 Rears, 757.0ms
# image 37/738 /content/datasets/interaction-set/Combined/AFBI048.jpg: 320x608 10 Heads, 8 Rears, 482.8ms
# image 38/738 /content/datasets/interaction-set/Combined/AFBI049.jpg: 320x608 10 Heads, 11 Rears, 495.8ms
# image 39/738 /content/datasets/interaction-set/Combined/AFBI050.jpg: 320x608 10 Heads, 10 Rears, 464.7ms
# image 40/738 /content/datasets/interaction-set/Combined/AFBI051.jpg: 320x608 9 Heads, 9 Rears, 493.4ms
# image 41/738 /content/datasets/interaction-set/Combined/AFBI052.jpg: 320x608 10 Heads, 9 Rears, 472.9ms
# image 42/738 /content/datasets/interaction-set/Combined/AFBI053.jpg: 320x608 10 Heads, 10 Rears, 474.4ms
# image 43/738 /content/datasets/interaction-set/Combined/AFBI054.jpg: 320x608 10 Heads, 10 Rears, 470.0ms
# image 44/738 /content/datasets/interaction-set/Combined/AFBI057.jpg: 320x608 10 Heads, 10 Rears, 483.6ms
# image 45/738 /content/datasets/interaction-set/Combined/AFBI058.jpg: 320x608 9 Heads, 11 Rears, 465.5ms
# image 46/738 /content/datasets/interaction-set/Combined/AFBI059.jpg: 320x608 10 Heads, 10 Rears, 479.6ms
# image 47/738 /content/datasets/interaction-set/Combined/AFBI060.jpg: 320x608 11 Heads, 9 Rears, 471.1ms
# image 48/738 /content/datasets/interaction-set/Combined/AFBI061.jpg: 320x608 10 Heads, 10 Rears, 479.3ms
# image 49/738 /content/datasets/interaction-set/Combined/AFBI062.jpg: 320x608 10 Heads, 10 Rears, 477.7ms
# image 50/738 /content/datasets/interaction-set/Combined/AFBI063.jpg: 320x608 10 Heads, 10 Rears, 487.5ms
# image 51/738 /content/datasets/interaction-set/Combined/AFBI064.jpg: 320x608 9 Heads, 9 Rears, 469.0ms
# image 52/738 /content/datasets/interaction-set/Combined/AFBI065.jpg: 320x608 9 Heads, 8 Rears, 476.0ms
# image 53/738 /content/datasets/interaction-set/Combined/AFBI066.jpg: 320x608 10 Heads, 9 Rears, 465.0ms
# image 54/738 /content/datasets/interaction-set/Combined/AFBI067.jpg: 320x608 9 Heads, 9 Rears, 474.2ms
# image 55/738 /content/datasets/interaction-set/Combined/AFBI068.jpg: 320x608 9 Heads, 8 Rears, 470.3ms
# image 56/738 /content/datasets/interaction-set/Combined/AFBI070.jpg: 320x608 8 Heads, 8 Rears, 485.6ms
# image 57/738 /content/datasets/interaction-set/Combined/AFBI071.jpg: 320x608 9 Heads, 9 Rears, 751.5ms
# image 58/738 /content/datasets/interaction-set/Combined/AFBI072.jpg: 320x608 9 Heads, 9 Rears, 813.3ms
# image 59/738 /content/datasets/interaction-set/Combined/AFBI073.jpg: 320x608 9 Heads, 9 Rears, 806.2ms
# image 60/738 /content/datasets/interaction-set/Combined/AFBI074.jpg: 320x608 9 Heads, 9 Rears, 773.9ms
# image 61/738 /content/datasets/interaction-set/Combined/AFBI075.jpg: 320x608 9 Heads, 10 Rears, 478.6ms
# image 62/738 /content/datasets/interaction-set/Combined/AFBI076.jpg: 320x608 10 Heads, 10 Rears, 480.9ms
# image 63/738 /content/datasets/interaction-set/Combined/AFBI077.jpg: 320x608 10 Heads, 10 Rears, 467.1ms
# image 64/738 /content/datasets/interaction-set/Combined/AFBI078.jpg: 320x608 10 Heads, 10 Rears, 488.8ms
# image 65/738 /content/datasets/interaction-set/Combined/AFBI079.jpg: 320x608 11 Heads, 10 Rears, 476.5ms
# image 66/738 /content/datasets/interaction-set/Combined/AFBI080.jpg: 320x608 11 Heads, 10 Rears, 482.7ms
# image 67/738 /content/datasets/interaction-set/Combined/AFBI081.jpg: 320x608 10 Heads, 10 Rears, 470.4ms
# image 68/738 /content/datasets/interaction-set/Combined/AFBI082.jpg: 320x608 10 Heads, 10 Rears, 481.3ms
# image 69/738 /content/datasets/interaction-set/Combined/AFBI083.jpg: 320x608 10 Heads, 11 Rears, 475.4ms
# image 70/738 /content/datasets/interaction-set/Combined/AFBI084.jpg: 320x608 10 Heads, 11 Rears, 484.2ms
# image 71/738 /content/datasets/interaction-set/Combined/AFBI085.jpg: 320x608 10 Heads, 10 Rears, 465.4ms
# image 72/738 /content/datasets/interaction-set/Combined/AFBI086.jpg: 320x608 10 Heads, 11 Rears, 477.1ms
# image 73/738 /content/datasets/interaction-set/Combined/AFBI087.jpg: 320x608 10 Heads, 11 Rears, 464.3ms
# image 74/738 /content/datasets/interaction-set/Combined/AFBI088.jpg: 320x608 10 Heads, 10 Rears, 479.9ms
# image 75/738 /content/datasets/interaction-set/Combined/AFBI089.jpg: 320x608 11 Heads, 10 Rears, 463.4ms
# image 76/738 /content/datasets/interaction-set/Combined/AFBI090.jpg: 320x608 10 Heads, 10 Rears, 482.0ms
# image 77/738 /content/datasets/interaction-set/Combined/AFBI091.jpg: 320x608 10 Heads, 11 Rears, 481.9ms
# image 78/738 /content/datasets/interaction-set/Combined/AFBI092.jpg: 320x608 10 Heads, 11 Rears, 484.6ms
# image 79/738 /content/datasets/interaction-set/Combined/AFBI093.jpg: 320x608 10 Heads, 10 Rears, 466.8ms
# image 80/738 /content/datasets/interaction-set/Combined/AFBI094.jpg: 320x608 10 Heads, 11 Rears, 484.1ms
# image 81/738 /content/datasets/interaction-set/Combined/AFBI095.jpg: 320x608 10 Heads, 10 Rears, 749.9ms
# image 82/738 /content/datasets/interaction-set/Combined/AFBI097.jpg: 352x608 9 Heads, 9 Rears, 893.5ms
# image 83/738 /content/datasets/interaction-set/Combined/AFBI098.jpg: 352x608 9 Heads, 9 Rears, 863.2ms
# image 84/738 /content/datasets/interaction-set/Combined/AFBI099.jpg: 352x608 9 Heads, 9 Rears, 779.1ms
# image 85/738 /content/datasets/interaction-set/Combined/AFBI100.jpg: 352x608 10 Heads, 9 Rears, 514.9ms
# image 86/738 /content/datasets/interaction-set/Combined/AFBI101.jpg: 352x608 9 Heads, 9 Rears, 531.8ms
# image 87/738 /content/datasets/interaction-set/Combined/AFBI102.jpg: 352x608 9 Heads, 9 Rears, 512.7ms
# image 88/738 /content/datasets/interaction-set/Combined/AFBI104.jpg: 352x608 9 Heads, 9 Rears, 522.0ms
# image 89/738 /content/datasets/interaction-set/Combined/AFBI105.jpg: 352x608 9 Heads, 9 Rears, 528.0ms
# image 90/738 /content/datasets/interaction-set/Combined/AFBI106.jpg: 352x608 9 Heads, 9 Rears, 516.3ms
# image 91/738 /content/datasets/interaction-set/Combined/AFBI107.jpg: 352x608 9 Heads, 9 Rears, 517.2ms
# image 92/738 /content/datasets/interaction-set/Combined/AFBI108.jpg: 352x608 9 Heads, 9 Rears, 509.9ms
# image 93/738 /content/datasets/interaction-set/Combined/AFBI109.jpg: 352x608 9 Heads, 9 Rears, 524.7ms
# image 94/738 /content/datasets/interaction-set/Combined/AFBI110.jpg: 352x608 8 Heads, 9 Rears, 519.9ms
# image 95/738 /content/datasets/interaction-set/Combined/AFBI111.jpg: 352x608 9 Heads, 9 Rears, 526.3ms
# image 96/738 /content/datasets/interaction-set/Combined/AFBI113.jpg: 352x608 9 Heads, 9 Rears, 517.2ms
# image 97/738 /content/datasets/interaction-set/Combined/AFBI114.jpg: 352x608 9 Heads, 9 Rears, 523.0ms
# image 98/738 /content/datasets/interaction-set/Combined/AFBI115.jpg: 352x608 8 Heads, 9 Rears, 521.4ms
# image 99/738 /content/datasets/interaction-set/Combined/AFBI116.jpg: 352x608 7 Heads, 9 Rears, 518.3ms
# image 100/738 /content/datasets/interaction-set/Combined/AFBI117.jpg: 352x608 9 Heads, 9 Rears, 531.6ms
# image 101/738 /content/datasets/interaction-set/Combined/AFBI118.jpg: 352x608 9 Heads, 9 Rears, 528.0ms
# image 102/738 /content/datasets/interaction-set/Combined/AFBI119.jpg: 352x608 9 Heads, 9 Rears, 519.7ms
# image 103/738 /content/datasets/interaction-set/Combined/AFBI120.jpg: 352x608 9 Heads, 9 Rears, 785.7ms
# image 104/738 /content/datasets/interaction-set/Combined/AFBI121.jpg: 352x608 9 Heads, 9 Rears, 857.4ms
# image 105/738 /content/datasets/interaction-set/Combined/AFBI122.jpg: 352x608 9 Heads, 9 Rears, 884.2ms
# image 106/738 /content/datasets/interaction-set/Combined/AFBI123.jpg: 352x608 9 Heads, 9 Rears, 809.0ms
# image 107/738 /content/datasets/interaction-set/Combined/AFBI125.jpg: 352x608 8 Heads, 9 Rears, 518.8ms
# image 108/738 /content/datasets/interaction-set/Combined/AFBI126.jpg: 352x608 9 Heads, 9 Rears, 530.3ms
# image 109/738 /content/datasets/interaction-set/Combined/AFBI127.jpg: 352x608 9 Heads, 9 Rears, 516.1ms
# image 110/738 /content/datasets/interaction-set/Combined/AFBI128.jpg: 352x608 9 Heads, 7 Rears, 533.0ms
# image 111/738 /content/datasets/interaction-set/Combined/AFBI131.jpg: 352x608 9 Heads, 9 Rears, 522.2ms
# image 112/738 /content/datasets/interaction-set/Combined/AFBI132.jpg: 352x608 9 Heads, 9 Rears, 538.3ms
# image 113/738 /content/datasets/interaction-set/Combined/AFBI133.jpg: 352x608 9 Heads, 9 Rears, 526.6ms
# image 114/738 /content/datasets/interaction-set/Combined/AFBI134.jpg: 352x608 6 Heads, 9 Rears, 528.3ms
# image 115/738 /content/datasets/interaction-set/Combined/AFBI135.jpg: 352x608 10 Heads, 8 Rears, 510.3ms
# image 116/738 /content/datasets/interaction-set/Combined/AFBI136.jpg: 352x608 8 Heads, 8 Rears, 519.4ms
# image 117/738 /content/datasets/interaction-set/Combined/AFBI137.jpg: 352x608 9 Heads, 9 Rears, 522.7ms
# image 118/738 /content/datasets/interaction-set/Combined/AFBI138.jpg: 352x608 9 Heads, 9 Rears, 522.3ms
# image 119/738 /content/datasets/interaction-set/Combined/AFBI139.jpg: 352x608 8 Heads, 9 Rears, 535.2ms
# image 120/738 /content/datasets/interaction-set/Combined/AFBI140.jpg: 352x608 8 Heads, 9 Rears, 517.9ms
# image 121/738 /content/datasets/interaction-set/Combined/AFBI141.jpg: 352x608 10 Heads, 9 Rears, 545.6ms
# image 122/738 /content/datasets/interaction-set/Combined/AFBI142.jpg: 352x608 9 Heads, 9 Rears, 526.1ms
# image 123/738 /content/datasets/interaction-set/Combined/AFBI143.jpg: 352x608 10 Heads, 9 Rears, 535.6ms
# image 124/738 /content/datasets/interaction-set/Combined/AFBI144.jpg: 352x608 8 Heads, 9 Rears, 522.1ms
# image 125/738 /content/datasets/interaction-set/Combined/AFBI146.jpg: 352x608 9 Heads, 10 Rears, 832.1ms
# image 126/738 /content/datasets/interaction-set/Combined/AFBI147.jpg: 352x608 9 Heads, 9 Rears, 874.1ms
# image 127/738 /content/datasets/interaction-set/Combined/AFBI148.jpg: 352x608 9 Heads, 10 Rears, 871.7ms
# image 128/738 /content/datasets/interaction-set/Combined/AFBI149.jpg: 352x608 8 Heads, 9 Rears, 803.8ms
# image 129/738 /content/datasets/interaction-set/Combined/AFBI150.jpg: 352x608 7 Heads, 8 Rears, 519.8ms
# image 130/738 /content/datasets/interaction-set/Combined/AFBI152.jpg: 352x608 8 Heads, 8 Rears, 540.5ms
# image 131/738 /content/datasets/interaction-set/Combined/AFBI153.jpg: 352x608 10 Heads, 9 Rears, 517.5ms
# image 132/738 /content/datasets/interaction-set/Combined/AFBI157.jpg: 352x608 8 Heads, 9 Rears, 535.9ms
# image 133/738 /content/datasets/interaction-set/Combined/AFBI158.jpg: 352x608 8 Heads, 8 Rears, 524.4ms
# image 134/738 /content/datasets/interaction-set/Combined/AFBI159.jpg: 352x608 8 Heads, 8 Rears, 533.7ms
# image 135/738 /content/datasets/interaction-set/Combined/AFBI160.jpg: 352x608 9 Heads, 10 Rears, 531.6ms
# image 136/738 /content/datasets/interaction-set/Combined/AFBI161.jpg: 352x608 8 Heads, 9 Rears, 540.4ms
# image 137/738 /content/datasets/interaction-set/Combined/AFBI162.jpg: 352x608 9 Heads, 9 Rears, 541.6ms
# image 138/738 /content/datasets/interaction-set/Combined/AFBI163.jpg: 352x608 9 Heads, 9 Rears, 536.5ms
# image 139/738 /content/datasets/interaction-set/Combined/AFBI164.jpg: 352x608 9 Heads, 10 Rears, 560.2ms
# image 140/738 /content/datasets/interaction-set/Combined/AFBI165.jpg: 352x608 8 Heads, 10 Rears, 527.1ms
# image 141/738 /content/datasets/interaction-set/Combined/AFBI166.jpg: 352x608 9 Heads, 9 Rears, 537.9ms
# image 142/738 /content/datasets/interaction-set/Combined/AFBI167.jpg: 352x608 9 Heads, 9 Rears, 519.1ms
# image 143/738 /content/datasets/interaction-set/Combined/AFBI168.jpg: 352x608 9 Heads, 9 Rears, 534.4ms
# image 144/738 /content/datasets/interaction-set/Combined/AFBI169.jpg: 352x608 9 Heads, 9 Rears, 538.4ms
# image 145/738 /content/datasets/interaction-set/Combined/AFBI170.jpg: 352x608 9 Heads, 9 Rears, 548.9ms
# image 146/738 /content/datasets/interaction-set/Combined/AFBI171.jpg: 352x608 9 Heads, 9 Rears, 604.2ms
# image 147/738 /content/datasets/interaction-set/Combined/AFBI172.jpg: 352x608 8 Heads, 9 Rears, 872.1ms
# image 148/738 /content/datasets/interaction-set/Combined/AFBI173.jpg: 352x608 9 Heads, 9 Rears, 898.6ms
# image 149/738 /content/datasets/interaction-set/Combined/AFBI174.jpg: 352x608 9 Heads, 9 Rears, 868.4ms
# image 150/738 /content/datasets/interaction-set/Combined/AFBI175.jpg: 352x608 9 Heads, 9 Rears, 678.5ms
# image 151/738 /content/datasets/interaction-set/Combined/AFBI176.jpg: 352x608 9 Heads, 9 Rears, 520.8ms
# image 152/738 /content/datasets/interaction-set/Combined/AFBI177.jpg: 352x608 9 Heads, 9 Rears, 529.6ms
# image 153/738 /content/datasets/interaction-set/Combined/AFBI178.jpg: 352x608 9 Heads, 9 Rears, 523.6ms
# image 154/738 /content/datasets/interaction-set/Combined/AFBI179.jpg: 352x608 8 Heads, 9 Rears, 542.8ms
# image 155/738 /content/datasets/interaction-set/Combined/AFBI180.jpg: 352x608 8 Heads, 11 Rears, 536.0ms
# image 156/738 /content/datasets/interaction-set/Combined/AFBI181.jpg: 352x608 9 Heads, 9 Rears, 537.5ms
# image 157/738 /content/datasets/interaction-set/Combined/AFBI183.jpg: 352x608 9 Heads, 9 Rears, 539.6ms
# image 158/738 /content/datasets/interaction-set/Combined/AFBI184.jpg: 352x608 9 Heads, 9 Rears, 532.4ms
# image 159/738 /content/datasets/interaction-set/Combined/AFBI185.jpg: 352x608 9 Heads, 9 Rears, 546.4ms
# image 160/738 /content/datasets/interaction-set/Combined/AFBI186.jpg: 352x608 9 Heads, 8 Rears, 1145.1ms
# image 161/738 /content/datasets/interaction-set/Combined/AFBI187.jpg: 352x608 8 Heads, 9 Rears, 543.1ms
# image 162/738 /content/datasets/interaction-set/Combined/AFBI188.jpg: 352x608 7 Heads, 10 Rears, 534.5ms
# image 163/738 /content/datasets/interaction-set/Combined/AFBI189.jpg: 352x608 9 Heads, 9 Rears, 531.7ms
# image 164/738 /content/datasets/interaction-set/Combined/AFBI190.jpg: 352x608 10 Heads, 9 Rears, 526.1ms
# image 165/738 /content/datasets/interaction-set/Combined/AFBI191.jpg: 352x608 12 Heads, 9 Rears, 541.6ms
# image 166/738 /content/datasets/interaction-set/Combined/AFBI192.jpg: 352x608 9 Heads, 9 Rears, 531.0ms
# image 167/738 /content/datasets/interaction-set/Combined/AFBI193.jpg: 352x608 8 Heads, 9 Rears, 768.2ms
# image 168/738 /content/datasets/interaction-set/Combined/AFBI194.jpg: 352x608 9 Heads, 9 Rears, 887.4ms
# image 169/738 /content/datasets/interaction-set/Combined/AFBI195.jpg: 352x608 9 Heads, 9 Rears, 868.6ms
# image 170/738 /content/datasets/interaction-set/Combined/AFBI196.jpg: 352x608 9 Heads, 9 Rears, 849.0ms
# image 171/738 /content/datasets/interaction-set/Combined/AFBI197.jpg: 352x608 9 Heads, 9 Rears, 527.0ms
# image 172/738 /content/datasets/interaction-set/Combined/AFBI198.jpg: 352x608 9 Heads, 9 Rears, 543.5ms
# image 173/738 /content/datasets/interaction-set/Combined/AFBI199.jpg: 352x608 9 Heads, 9 Rears, 523.7ms
# image 174/738 /content/datasets/interaction-set/Combined/AFBI200.jpg: 352x608 8 Heads, 8 Rears, 544.8ms
# image 175/738 /content/datasets/interaction-set/Combined/AFBI201.jpg: 352x608 9 Heads, 9 Rears, 526.7ms
# image 176/738 /content/datasets/interaction-set/Combined/AFBI202.jpg: 352x608 9 Heads, 9 Rears, 546.5ms
# image 177/738 /content/datasets/interaction-set/Combined/AFBI203.jpg: 352x608 9 Heads, 9 Rears, 540.1ms
# image 178/738 /content/datasets/interaction-set/Combined/AFBI204.jpg: 352x608 9 Heads, 9 Rears, 543.0ms
# image 179/738 /content/datasets/interaction-set/Combined/AFBI207.jpg: 352x608 9 Heads, 9 Rears, 537.0ms
# image 180/738 /content/datasets/interaction-set/Combined/AFBI208.jpg: 352x608 9 Heads, 9 Rears, 538.1ms
# image 181/738 /content/datasets/interaction-set/Combined/AFBI209.jpg: 352x608 9 Heads, 9 Rears, 547.2ms
# image 182/738 /content/datasets/interaction-set/Combined/AFBI210.jpg: 352x608 9 Heads, 9 Rears, 522.6ms
# image 183/738 /content/datasets/interaction-set/Combined/AFBI211.jpg: 352x608 9 Heads, 9 Rears, 548.1ms
# image 184/738 /content/datasets/interaction-set/Combined/AFBI212.jpg: 352x608 9 Heads, 9 Rears, 540.9ms
# image 185/738 /content/datasets/interaction-set/Combined/AFBI213.jpg: 352x608 9 Heads, 9 Rears, 533.7ms
# image 186/738 /content/datasets/interaction-set/Combined/AFBI214.jpg: 352x608 9 Heads, 9 Rears, 538.4ms
# image 187/738 /content/datasets/interaction-set/Combined/AFBI215.jpg: 352x608 10 Heads, 8 Rears, 556.5ms
# image 188/738 /content/datasets/interaction-set/Combined/AFBI216.jpg: 352x608 9 Heads, 8 Rears, 576.6ms
# image 189/738 /content/datasets/interaction-set/Combined/AFBI217.jpg: 352x608 9 Heads, 9 Rears, 910.4ms
# image 190/738 /content/datasets/interaction-set/Combined/AFBI218.jpg: 352x608 9 Heads, 9 Rears, 874.2ms
# image 191/738 /content/datasets/interaction-set/Combined/AFBI219.jpg: 352x608 9 Heads, 9 Rears, 910.5ms
# image 192/738 /content/datasets/interaction-set/Combined/AFBI223.jpg: 352x608 8 Heads, 9 Rears, 659.7ms
# image 193/738 /content/datasets/interaction-set/Combined/AFBI224.jpg: 352x608 8 Heads, 9 Rears, 535.7ms
# image 194/738 /content/datasets/interaction-set/Combined/AFBI225.jpg: 352x608 8 Heads, 9 Rears, 547.6ms
# image 195/738 /content/datasets/interaction-set/Combined/AFBI226.jpg: 352x608 8 Heads, 9 Rears, 532.4ms
# image 196/738 /content/datasets/interaction-set/Combined/AFBI227.jpg: 352x608 7 Heads, 9 Rears, 547.6ms
# image 197/738 /content/datasets/interaction-set/Combined/AFBI228.jpg: 352x608 9 Heads, 9 Rears, 544.6ms
# image 198/738 /content/datasets/interaction-set/Combined/AFBI229.jpg: 352x608 9 Heads, 9 Rears, 534.6ms
# image 199/738 /content/datasets/interaction-set/Combined/AFBI230.jpg: 352x608 8 Heads, 9 Rears, 542.4ms
# image 200/738 /content/datasets/interaction-set/Combined/AFBI231.jpg: 352x608 9 Heads, 9 Rears, 525.0ms
# image 201/738 /content/datasets/interaction-set/Combined/AFBI232.jpg: 352x608 8 Heads, 9 Rears, 537.5ms
# image 202/738 /content/datasets/interaction-set/Combined/AFBI233.jpg: 352x608 8 Heads, 10 Rears, 531.1ms
# image 203/738 /content/datasets/interaction-set/Combined/AFBI234.jpg: 352x608 9 Heads, 9 Rears, 542.0ms
# image 204/738 /content/datasets/interaction-set/Combined/AFBI235.jpg: 352x608 8 Heads, 7 Rears, 520.9ms
# image 205/738 /content/datasets/interaction-set/Combined/AFBI236.jpg: 352x608 8 Heads, 8 Rears, 551.3ms
# image 206/738 /content/datasets/interaction-set/Combined/AFBI237.jpg: 352x608 8 Heads, 8 Rears, 523.8ms
# image 207/738 /content/datasets/interaction-set/Combined/AFBI238.jpg: 352x608 8 Heads, 8 Rears, 538.1ms
# image 208/738 /content/datasets/interaction-set/Combined/AFBI239.jpg: 352x608 7 Heads, 8 Rears, 532.7ms
# image 209/738 /content/datasets/interaction-set/Combined/AFBI240.jpg: 352x608 8 Heads, 8 Rears, 528.4ms
# image 210/738 /content/datasets/interaction-set/Combined/AFBI241.jpg: 352x608 7 Heads, 8 Rears, 782.4ms
# image 211/738 /content/datasets/interaction-set/Combined/AFBI242.jpg: 352x608 8 Heads, 8 Rears, 900.8ms
# image 212/738 /content/datasets/interaction-set/Combined/AFBI244.jpg: 352x608 8 Heads, 8 Rears, 900.0ms
# image 213/738 /content/datasets/interaction-set/Combined/AFBI245.jpg: 352x608 8 Heads, 8 Rears, 1461.7ms
# image 214/738 /content/datasets/interaction-set/Combined/AFBI246.jpg: 352x608 8 Heads, 9 Rears, 541.3ms
# image 215/738 /content/datasets/interaction-set/Combined/AFBI247.jpg: 352x608 7 Heads, 8 Rears, 524.5ms
# image 216/738 /content/datasets/interaction-set/Combined/AFBI248.jpg: 352x608 8 Heads, 9 Rears, 548.7ms
# image 217/738 /content/datasets/interaction-set/Combined/AFBI249.jpg: 352x608 8 Heads, 9 Rears, 528.7ms
# image 218/738 /content/datasets/interaction-set/Combined/AFBI250.jpg: 352x608 8 Heads, 7 Rears, 546.8ms
# image 219/738 /content/datasets/interaction-set/Combined/AFBI252.jpg: 352x608 8 Heads, 9 Rears, 523.1ms
# image 220/738 /content/datasets/interaction-set/Combined/AFBI254.jpg: 352x608 8 Heads, 10 Rears, 543.9ms
# image 221/738 /content/datasets/interaction-set/Combined/AFBI255.jpg: 352x608 9 Heads, 9 Rears, 531.4ms
# image 222/738 /content/datasets/interaction-set/Combined/AFBI256.jpg: 352x608 9 Heads, 8 Rears, 523.5ms
# image 223/738 /content/datasets/interaction-set/Combined/AFBI257.jpg: 352x608 8 Heads, 8 Rears, 530.0ms
# image 224/738 /content/datasets/interaction-set/Combined/AFBI258.jpg: 352x608 8 Heads, 9 Rears, 529.6ms
# image 225/738 /content/datasets/interaction-set/Combined/AFBI259.jpg: 352x608 8 Heads, 9 Rears, 529.9ms
# image 226/738 /content/datasets/interaction-set/Combined/AFBI260.jpg: 352x608 9 Heads, 9 Rears, 522.7ms
# image 227/738 /content/datasets/interaction-set/Combined/AFBI261.jpg: 352x608 9 Heads, 9 Rears, 562.3ms
# image 228/738 /content/datasets/interaction-set/Combined/AFBI262.jpg: 352x608 9 Heads, 9 Rears, 526.5ms
# image 229/738 /content/datasets/interaction-set/Combined/AFBI263.jpg: 352x608 9 Heads, 9 Rears, 535.9ms
# image 230/738 /content/datasets/interaction-set/Combined/AFBI264.jpg: 352x608 9 Heads, 9 Rears, 524.8ms
# image 231/738 /content/datasets/interaction-set/Combined/AFBI265.jpg: 352x608 9 Heads, 10 Rears, 859.3ms
# image 232/738 /content/datasets/interaction-set/Combined/AFBI266.jpg: 352x608 8 Heads, 9 Rears, 910.3ms
# image 233/738 /content/datasets/interaction-set/Combined/AFBI267.jpg: 352x608 8 Heads, 8 Rears, 902.7ms
# image 234/738 /content/datasets/interaction-set/Combined/AFBI268.jpg: 352x608 8 Heads, 8 Rears, 741.0ms
# image 235/738 /content/datasets/interaction-set/Combined/AFBI269.jpg: 352x608 7 Heads, 7 Rears, 533.7ms
# image 236/738 /content/datasets/interaction-set/Combined/AFBI270.jpg: 352x608 7 Heads, 8 Rears, 538.6ms
# image 237/738 /content/datasets/interaction-set/Combined/AFBI271.jpg: 352x608 8 Heads, 8 Rears, 525.5ms
# image 238/738 /content/datasets/interaction-set/Combined/AFBI272.jpg: 352x608 7 Heads, 8 Rears, 540.5ms
# image 239/738 /content/datasets/interaction-set/Combined/AFBI273.jpg: 352x608 7 Heads, 8 Rears, 532.4ms
# image 240/738 /content/datasets/interaction-set/Combined/AFBI274.jpg: 352x608 8 Heads, 8 Rears, 538.0ms
# image 241/738 /content/datasets/interaction-set/Combined/AFBI275.jpg: 352x608 9 Heads, 8 Rears, 521.4ms
# image 242/738 /content/datasets/interaction-set/Combined/AFBI276.jpg: 352x608 7 Heads, 8 Rears, 539.7ms
# image 243/738 /content/datasets/interaction-set/Combined/AFBI277.jpg: 352x608 7 Heads, 7 Rears, 542.7ms
# image 244/738 /content/datasets/interaction-set/Combined/AFBI278.jpg: 352x608 8 Heads, 8 Rears, 541.1ms
# image 245/738 /content/datasets/interaction-set/Combined/AFBI279.jpg: 352x608 7 Heads, 8 Rears, 529.8ms
# image 246/738 /content/datasets/interaction-set/Combined/AFBI280.jpg: 352x608 8 Heads, 8 Rears, 530.1ms
# image 247/738 /content/datasets/interaction-set/Combined/AFBI281.jpg: 352x608 6 Heads, 8 Rears, 536.2ms
# image 248/738 /content/datasets/interaction-set/Combined/AFBI282.jpg: 352x608 7 Heads, 8 Rears, 526.4ms
# image 249/738 /content/datasets/interaction-set/Combined/AFBI283.jpg: 352x608 7 Heads, 8 Rears, 545.2ms
# image 250/738 /content/datasets/interaction-set/Combined/AFBI284.jpg: 352x608 8 Heads, 9 Rears, 524.9ms
# image 251/738 /content/datasets/interaction-set/Combined/AFBI285.jpg: 352x608 8 Heads, 8 Rears, 546.9ms
# image 252/738 /content/datasets/interaction-set/Combined/AFBI286.jpg: 320x608 9 Heads, 9 Rears, 588.1ms
# image 253/738 /content/datasets/interaction-set/Combined/AFBI287.jpg: 320x608 9 Heads, 9 Rears, 823.1ms
# image 254/738 /content/datasets/interaction-set/Combined/AFBI288.jpg: 320x608 10 Heads, 9 Rears, 801.2ms
# image 255/738 /content/datasets/interaction-set/Combined/AFBI289.jpg: 320x608 9 Heads, 9 Rears, 791.2ms
# image 256/738 /content/datasets/interaction-set/Combined/AFBI290.jpg: 320x608 10 Heads, 9 Rears, 653.3ms
# image 257/738 /content/datasets/interaction-set/Combined/AFBI291.jpg: 320x608 10 Heads, 9 Rears, 478.5ms
# image 258/738 /content/datasets/interaction-set/Combined/AFBI292.jpg: 320x608 9 Heads, 10 Rears, 484.9ms
# image 259/738 /content/datasets/interaction-set/Combined/AFBI293.jpg: 320x608 9 Heads, 10 Rears, 484.0ms
# image 260/738 /content/datasets/interaction-set/Combined/AFBI294.jpg: 320x608 12 Heads, 10 Rears, 497.9ms
# image 261/738 /content/datasets/interaction-set/Combined/AFBI295.jpg: 320x608 10 Heads, 10 Rears, 489.8ms
# image 262/738 /content/datasets/interaction-set/Combined/AFBI299.jpg: 320x608 9 Heads, 9 Rears, 473.9ms
# image 263/738 /content/datasets/interaction-set/Combined/AFBI300.jpg: 320x608 10 Heads, 10 Rears, 483.8ms
# image 264/738 /content/datasets/interaction-set/Combined/AFBI301.jpg: 320x608 10 Heads, 11 Rears, 494.5ms
# image 265/738 /content/datasets/interaction-set/Combined/AFBI302.jpg: 320x608 9 Heads, 11 Rears, 483.1ms
# image 266/738 /content/datasets/interaction-set/Combined/AFBI303.jpg: 320x608 8 Heads, 10 Rears, 689.9ms
# image 267/738 /content/datasets/interaction-set/Combined/AFBI304.jpg: 320x608 8 Heads, 10 Rears, 601.1ms
# image 268/738 /content/datasets/interaction-set/Combined/AFBI305.jpg: 320x608 8 Heads, 9 Rears, 490.7ms
# image 269/738 /content/datasets/interaction-set/Combined/AFBI306.jpg: 320x608 9 Heads, 10 Rears, 473.8ms
# image 270/738 /content/datasets/interaction-set/Combined/AFBI307.jpg: 320x608 9 Heads, 9 Rears, 493.2ms
# image 271/738 /content/datasets/interaction-set/Combined/AFBI308.jpg: 320x608 10 Heads, 9 Rears, 476.4ms
# image 272/738 /content/datasets/interaction-set/Combined/AFBI309.jpg: 320x608 9 Heads, 10 Rears, 493.3ms
# image 273/738 /content/datasets/interaction-set/Combined/AFBI310.jpg: 320x608 8 Heads, 10 Rears, 483.6ms
# image 274/738 /content/datasets/interaction-set/Combined/AFBI311.jpg: 320x608 9 Heads, 11 Rears, 495.2ms
# image 275/738 /content/datasets/interaction-set/Combined/AFBI312.jpg: 320x608 9 Heads, 8 Rears, 598.8ms
# image 276/738 /content/datasets/interaction-set/Combined/AFBI313.jpg: 320x608 8 Heads, 10 Rears, 785.3ms
# image 277/738 /content/datasets/interaction-set/Combined/AFBI315.jpg: 320x608 10 Heads, 10 Rears, 778.2ms
# image 278/738 /content/datasets/interaction-set/Combined/AFBI316.jpg: 320x608 11 Heads, 10 Rears, 787.0ms
# image 279/738 /content/datasets/interaction-set/Combined/AFBI317.jpg: 320x608 7 Heads, 9 Rears, 700.6ms
# image 280/738 /content/datasets/interaction-set/Combined/AFBI324.jpg: 320x608 8 Heads, 9 Rears, 492.4ms
# image 281/738 /content/datasets/interaction-set/Combined/AFBI325.jpg: 320x608 10 Heads, 8 Rears, 499.4ms
# image 282/738 /content/datasets/interaction-set/Combined/AFBI326.jpg: 320x608 8 Heads, 10 Rears, 475.4ms
# image 283/738 /content/datasets/interaction-set/Combined/AFBI327.jpg: 320x608 9 Heads, 10 Rears, 497.3ms
# image 284/738 /content/datasets/interaction-set/Combined/AFBI328.jpg: 320x608 9 Heads, 10 Rears, 496.0ms
# image 285/738 /content/datasets/interaction-set/Combined/AFBI329.jpg: 320x608 9 Heads, 9 Rears, 499.8ms
# image 286/738 /content/datasets/interaction-set/Combined/AFBI330.jpg: 320x608 8 Heads, 9 Rears, 475.9ms
# image 287/738 /content/datasets/interaction-set/Combined/AFBI331.jpg: 320x608 8 Heads, 11 Rears, 498.3ms
# image 288/738 /content/datasets/interaction-set/Combined/AFBI332.jpg: 320x608 7 Heads, 9 Rears, 487.1ms
# image 289/738 /content/datasets/interaction-set/Combined/AFBI333.jpg: 320x608 8 Heads, 9 Rears, 508.8ms
# image 290/738 /content/datasets/interaction-set/Combined/AFBI334.jpg: 320x608 9 Heads, 8 Rears, 491.4ms
# image 291/738 /content/datasets/interaction-set/Combined/AFBI335.jpg: 320x608 9 Heads, 9 Rears, 499.5ms
# image 292/738 /content/datasets/interaction-set/Combined/AFBI336.jpg: 320x608 10 Heads, 10 Rears, 498.1ms
# image 293/738 /content/datasets/interaction-set/Combined/AFBI337.jpg: 320x608 5 Heads, 9 Rears, 495.6ms
# image 294/738 /content/datasets/interaction-set/Combined/AFBI338.jpg: 320x608 8 Heads, 10 Rears, 484.0ms
# image 295/738 /content/datasets/interaction-set/Combined/AFBI339.jpg: 320x608 7 Heads, 10 Rears, 498.7ms
# image 296/738 /content/datasets/interaction-set/Combined/AFBI340.jpg: 320x608 7 Heads, 10 Rears, 487.9ms
# image 297/738 /content/datasets/interaction-set/Combined/AFBI341.jpg: 320x608 7 Heads, 9 Rears, 495.2ms
# image 298/738 /content/datasets/interaction-set/Combined/AFBI342.jpg: 320x608 7 Heads, 8 Rears, 479.7ms
# image 299/738 /content/datasets/interaction-set/Combined/AFBI343.jpg: 320x608 7 Heads, 9 Rears, 746.2ms
# image 300/738 /content/datasets/interaction-set/Combined/AFBI344.jpg: 320x608 9 Heads, 10 Rears, 876.7ms
# image 301/738 /content/datasets/interaction-set/Combined/AFBI345.jpg: 320x608 10 Heads, 9 Rears, 814.5ms
# image 302/738 /content/datasets/interaction-set/Combined/AFBI346.jpg: 320x608 9 Heads, 9 Rears, 789.1ms
# image 303/738 /content/datasets/interaction-set/Combined/AFBI347.jpg: 320x608 8 Heads, 10 Rears, 676.6ms
# image 304/738 /content/datasets/interaction-set/Combined/AFBI348.jpg: 320x608 9 Heads, 9 Rears, 785.4ms
# image 305/738 /content/datasets/interaction-set/Combined/AFBI349.jpg: 320x608 10 Heads, 9 Rears, 873.6ms
# image 306/738 /content/datasets/interaction-set/Combined/AFBI350.jpg: 320x608 9 Heads, 9 Rears, 822.6ms
# image 307/738 /content/datasets/interaction-set/Combined/AFBI351.jpg: 320x608 7 Heads, 8 Rears, 1047.6ms
# image 308/738 /content/datasets/interaction-set/Combined/AFBI352.jpg: 320x608 8 Heads, 9 Rears, 1032.9ms
# image 309/738 /content/datasets/interaction-set/Combined/AFBI353.jpg: 320x608 7 Heads, 9 Rears, 1163.7ms
# image 310/738 /content/datasets/interaction-set/Combined/AFBI354.jpg: 320x608 9 Heads, 10 Rears, 951.7ms
# image 311/738 /content/datasets/interaction-set/Combined/AFBI355.jpg: 320x608 7 Heads, 9 Rears, 1027.2ms
# image 312/738 /content/datasets/interaction-set/Combined/AFBI356.jpg: 320x608 6 Heads, 9 Rears, 1198.8ms
# image 313/738 /content/datasets/interaction-set/Combined/AFBI357.jpg: 320x608 8 Heads, 8 Rears, 790.2ms
# image 314/738 /content/datasets/interaction-set/Combined/AFBI358.jpg: 320x608 8 Heads, 9 Rears, 807.8ms
# image 315/738 /content/datasets/interaction-set/Combined/AFBI359.jpg: 320x608 7 Heads, 9 Rears, 796.5ms
# image 316/738 /content/datasets/interaction-set/Combined/AFBI361.jpg: 320x608 9 Heads, 9 Rears, 793.5ms
# image 317/738 /content/datasets/interaction-set/Combined/AFBI362.jpg: 320x608 9 Heads, 9 Rears, 513.0ms
# image 318/738 /content/datasets/interaction-set/Combined/AFBI363.jpg: 320x608 10 Heads, 9 Rears, 478.3ms
# image 319/738 /content/datasets/interaction-set/Combined/AFBI366.jpg: 320x608 9 Heads, 9 Rears, 495.7ms
# image 320/738 /content/datasets/interaction-set/Combined/AFBI367.jpg: 320x608 9 Heads, 9 Rears, 482.1ms
# image 321/738 /content/datasets/interaction-set/Combined/AFBI368.jpg: 320x608 10 Heads, 9 Rears, 500.6ms
# image 322/738 /content/datasets/interaction-set/Combined/AFBI369.jpg: 320x608 8 Heads, 9 Rears, 474.1ms
# image 323/738 /content/datasets/interaction-set/Combined/AFBI370.jpg: 320x608 8 Heads, 9 Rears, 506.8ms
# image 324/738 /content/datasets/interaction-set/Combined/AFBI371.jpg: 320x608 8 Heads, 9 Rears, 475.7ms
# image 325/738 /content/datasets/interaction-set/Combined/AFBI372.jpg: 320x608 8 Heads, 9 Rears, 499.6ms
# image 326/738 /content/datasets/interaction-set/Combined/AFBI373.jpg: 320x608 7 Heads, 9 Rears, 477.5ms
# image 327/738 /content/datasets/interaction-set/Combined/AFBI374.jpg: 320x608 9 Heads, 9 Rears, 491.2ms
# image 328/738 /content/datasets/interaction-set/Combined/AFBI377.jpg: 320x608 8 Heads, 9 Rears, 492.6ms
# image 329/738 /content/datasets/interaction-set/Combined/AFBI378.jpg: 320x608 7 Heads, 9 Rears, 491.5ms
# image 330/738 /content/datasets/interaction-set/Combined/AFBI379.jpg: 320x608 9 Heads, 10 Rears, 480.4ms
# image 331/738 /content/datasets/interaction-set/Combined/AFBI380.jpg: 320x608 8 Heads, 10 Rears, 487.0ms
# image 332/738 /content/datasets/interaction-set/Combined/AFBI381.jpg: 320x608 9 Heads, 9 Rears, 475.8ms
# image 333/738 /content/datasets/interaction-set/Combined/AFBI382.jpg: 320x608 8 Heads, 9 Rears, 503.2ms
# image 334/738 /content/datasets/interaction-set/Combined/AFBI383.jpg: 320x608 9 Heads, 9 Rears, 482.0ms
# image 335/738 /content/datasets/interaction-set/Combined/AFBI384.jpg: 320x608 8 Heads, 9 Rears, 492.0ms
# image 336/738 /content/datasets/interaction-set/Combined/AFBI385.jpg: 320x608 8 Heads, 9 Rears, 593.8ms
# image 337/738 /content/datasets/interaction-set/Combined/AFBI387.jpg: 320x608 8 Heads, 9 Rears, 804.1ms
# image 338/738 /content/datasets/interaction-set/Combined/AFBI388.jpg: 320x608 9 Heads, 9 Rears, 789.7ms
# image 339/738 /content/datasets/interaction-set/Combined/AFBI390.jpg: 320x608 8 Heads, 10 Rears, 798.7ms
# image 340/738 /content/datasets/interaction-set/Combined/AFBI391.jpg: 320x608 8 Heads, 9 Rears, 675.8ms
# image 341/738 /content/datasets/interaction-set/Combined/AFBI392.jpg: 320x608 8 Heads, 9 Rears, 495.5ms
# image 342/738 /content/datasets/interaction-set/Combined/AFBI393.jpg: 320x608 9 Heads, 9 Rears, 480.0ms
# image 343/738 /content/datasets/interaction-set/Combined/AFBI394.jpg: 320x608 7 Heads, 8 Rears, 486.1ms
# image 344/738 /content/datasets/interaction-set/Combined/AFBI395.jpg: 320x608 7 Heads, 8 Rears, 488.5ms
# image 345/738 /content/datasets/interaction-set/Combined/AFBI396.jpg: 320x608 8 Heads, 9 Rears, 484.6ms
# image 346/738 /content/datasets/interaction-set/Combined/AFBI397.jpg: 320x608 8 Heads, 7 Rears, 480.6ms
# image 347/738 /content/datasets/interaction-set/Combined/AFBI398.jpg: 320x608 8 Heads, 8 Rears, 488.4ms
# image 348/738 /content/datasets/interaction-set/Combined/AFBI399.jpg: 320x608 9 Heads, 9 Rears, 488.2ms
# image 349/738 /content/datasets/interaction-set/Combined/AFBI400.jpg: 320x608 9 Heads, 9 Rears, 491.1ms
# image 350/738 /content/datasets/interaction-set/Combined/AFBI401.jpg: 320x608 7 Heads, 10 Rears, 478.7ms
# image 351/738 /content/datasets/interaction-set/Combined/AFBI402.jpg: 320x608 9 Heads, 8 Rears, 482.9ms
# image 352/738 /content/datasets/interaction-set/Combined/AFBI403.jpg: 320x608 8 Heads, 9 Rears, 494.3ms
# image 353/738 /content/datasets/interaction-set/Combined/AFBI404.jpg: 320x608 9 Heads, 9 Rears, 491.4ms
# image 354/738 /content/datasets/interaction-set/Combined/AFBI405.jpg: 320x608 8 Heads, 9 Rears, 485.4ms
# image 355/738 /content/datasets/interaction-set/Combined/AFBI406.jpg: 320x608 8 Heads, 9 Rears, 490.8ms
# image 356/738 /content/datasets/interaction-set/Combined/AFBI407.jpg: 320x608 9 Heads, 9 Rears, 480.5ms
# image 357/738 /content/datasets/interaction-set/Combined/AFBI408.jpg: 320x608 9 Heads, 9 Rears, 501.2ms
# image 358/738 /content/datasets/interaction-set/Combined/AFBI409.jpg: 320x608 8 Heads, 9 Rears, 480.1ms
# image 359/738 /content/datasets/interaction-set/Combined/AFBI410.jpg: 320x608 10 Heads, 9 Rears, 486.6ms
# image 360/738 /content/datasets/interaction-set/Combined/AFBI411.jpg: 320x608 9 Heads, 9 Rears, 692.1ms
# image 361/738 /content/datasets/interaction-set/Combined/AFBI412.jpg: 320x608 8 Heads, 9 Rears, 793.8ms
# image 362/738 /content/datasets/interaction-set/Combined/AFBI413.jpg: 320x608 8 Heads, 9 Rears, 792.8ms
# image 363/738 /content/datasets/interaction-set/Combined/AFBI414.jpg: 320x608 8 Heads, 9 Rears, 795.3ms
# image 364/738 /content/datasets/interaction-set/Combined/AFBI415.jpg: 320x608 9 Heads, 9 Rears, 565.4ms
# image 365/738 /content/datasets/interaction-set/Combined/AFBI416.jpg: 352x608 11 Heads, 10 Rears, 522.7ms
# image 366/738 /content/datasets/interaction-set/Combined/AFBI417.jpg: 352x608 8 Heads, 9 Rears, 525.0ms
# image 367/738 /content/datasets/interaction-set/Combined/AFBI418.jpg: 352x608 8 Heads, 9 Rears, 524.6ms
# image 368/738 /content/datasets/interaction-set/Combined/AFBI419.jpg: 352x608 10 Heads, 8 Rears, 533.4ms
# image 369/738 /content/datasets/interaction-set/Combined/AFBI420.jpg: 352x608 9 Heads, 9 Rears, 526.0ms
# image 370/738 /content/datasets/interaction-set/Combined/AFBI421.jpg: 352x608 8 Heads, 10 Rears, 526.7ms
# image 371/738 /content/datasets/interaction-set/Combined/AFBI422.jpg: 352x608 10 Heads, 9 Rears, 525.0ms
# image 372/738 /content/datasets/interaction-set/Combined/AFBI423.jpg: 352x608 8 Heads, 9 Rears, 533.5ms
# image 373/738 /content/datasets/interaction-set/Combined/AFBI425.jpg: 352x608 11 Heads, 10 Rears, 520.4ms
# image 374/738 /content/datasets/interaction-set/Combined/AFBI426.jpg: 352x608 7 Heads, 10 Rears, 534.2ms
# image 375/738 /content/datasets/interaction-set/Combined/AFBI427.jpg: 352x608 9 Heads, 9 Rears, 541.4ms
# image 376/738 /content/datasets/interaction-set/Combined/AFBI429.jpg: 352x608 10 Heads, 10 Rears, 531.3ms
# image 377/738 /content/datasets/interaction-set/Combined/AFBI430.jpg: 352x608 10 Heads, 10 Rears, 533.6ms
# image 378/738 /content/datasets/interaction-set/Combined/AFBI431.jpg: 352x608 8 Heads, 9 Rears, 535.0ms
# image 379/738 /content/datasets/interaction-set/Combined/AFBI432.jpg: 352x608 8 Heads, 8 Rears, 535.8ms
# image 380/738 /content/datasets/interaction-set/Combined/AFBI433.jpg: 352x608 9 Heads, 8 Rears, 519.7ms
# image 381/738 /content/datasets/interaction-set/Combined/AFBI435.jpg: 352x608 8 Heads, 7 Rears, 549.1ms
# image 382/738 /content/datasets/interaction-set/Combined/AFBI436.jpg: 352x608 8 Heads, 8 Rears, 663.3ms
# image 383/738 /content/datasets/interaction-set/Combined/AFBI437.jpg: 352x608 10 Heads, 9 Rears, 888.7ms
# image 384/738 /content/datasets/interaction-set/Combined/AFBI438.jpg: 352x608 9 Heads, 10 Rears, 894.6ms
# image 385/738 /content/datasets/interaction-set/Combined/AFBI441.jpg: 352x608 10 Heads, 9 Rears, 855.3ms
# image 386/738 /content/datasets/interaction-set/Combined/AFBI442.jpg: 352x608 7 Heads, 6 Rears, 577.9ms
# image 387/738 /content/datasets/interaction-set/Combined/AFBI443.jpg: 352x608 8 Heads, 8 Rears, 519.9ms
# image 388/738 /content/datasets/interaction-set/Combined/AFBI445.jpg: 352x608 7 Heads, 7 Rears, 530.6ms
# image 389/738 /content/datasets/interaction-set/Combined/AFBI446.jpg: 352x608 8 Heads, 8 Rears, 523.4ms
# image 390/738 /content/datasets/interaction-set/Combined/AFBI447.jpg: 352x608 8 Heads, 8 Rears, 535.4ms
# image 391/738 /content/datasets/interaction-set/Combined/AFBI448.jpg: 352x608 8 Heads, 8 Rears, 516.1ms
# image 392/738 /content/datasets/interaction-set/Combined/AFBI449.jpg: 352x608 9 Heads, 7 Rears, 535.5ms
# image 393/738 /content/datasets/interaction-set/Combined/AFBI450.jpg: 352x608 8 Heads, 9 Rears, 514.7ms
# image 394/738 /content/datasets/interaction-set/Combined/AFBI451.jpg: 352x608 7 Heads, 9 Rears, 541.0ms
# image 395/738 /content/datasets/interaction-set/Combined/AFBI452.jpg: 352x608 9 Heads, 10 Rears, 549.1ms
# image 396/738 /content/datasets/interaction-set/Combined/AFBI454.jpg: 352x608 8 Heads, 8 Rears, 560.5ms
# image 397/738 /content/datasets/interaction-set/Combined/AFBI455.jpg: 352x608 7 Heads, 8 Rears, 560.6ms
# image 398/738 /content/datasets/interaction-set/Combined/AFBI456.jpg: 352x608 7 Heads, 9 Rears, 525.3ms
# image 399/738 /content/datasets/interaction-set/Combined/AFBI457.jpg: 352x608 7 Heads, 10 Rears, 537.4ms
# image 400/738 /content/datasets/interaction-set/Combined/AFBI458.jpg: 352x608 8 Heads, 10 Rears, 524.6ms
# image 401/738 /content/datasets/interaction-set/Combined/AFBI459.jpg: 352x608 9 Heads, 10 Rears, 525.3ms
# image 402/738 /content/datasets/interaction-set/Combined/AFBI460.jpg: 352x608 9 Heads, 9 Rears, 519.0ms
# image 403/738 /content/datasets/interaction-set/Combined/AFBI461.jpg: 352x608 9 Heads, 8 Rears, 532.6ms
# image 404/738 /content/datasets/interaction-set/Combined/AFBI462.jpg: 352x608 8 Heads, 8 Rears, 823.3ms
# image 405/738 /content/datasets/interaction-set/Combined/AFBI464.jpg: 352x608 8 Heads, 8 Rears, 887.5ms
# image 406/738 /content/datasets/interaction-set/Combined/AFBI465.jpg: 352x608 8 Heads, 8 Rears, 875.0ms
# image 407/738 /content/datasets/interaction-set/Combined/AFBI466.jpg: 352x608 8 Heads, 8 Rears, 771.6ms
# image 408/738 /content/datasets/interaction-set/Combined/AFBI467.jpg: 352x608 10 Heads, 8 Rears, 533.9ms
# image 409/738 /content/datasets/interaction-set/Combined/AFBI468.jpg: 352x608 10 Heads, 8 Rears, 539.0ms
# image 410/738 /content/datasets/interaction-set/Combined/AFBI469.jpg: 352x608 9 Heads, 10 Rears, 532.3ms
# image 411/738 /content/datasets/interaction-set/Combined/AFBI470.jpg: 352x608 9 Heads, 9 Rears, 522.2ms
# image 412/738 /content/datasets/interaction-set/Combined/AFBI471.jpg: 352x608 9 Heads, 9 Rears, 531.8ms
# image 413/738 /content/datasets/interaction-set/Combined/AFBI472.jpg: 352x608 10 Heads, 9 Rears, 532.2ms
# image 414/738 /content/datasets/interaction-set/Combined/AFBI473.jpg: 352x608 9 Heads, 8 Rears, 528.7ms
# image 415/738 /content/datasets/interaction-set/Combined/AFBI474.jpg: 352x608 10 Heads, 9 Rears, 534.1ms
# image 416/738 /content/datasets/interaction-set/Combined/AFBI475.jpg: 352x608 9 Heads, 9 Rears, 535.5ms
# image 417/738 /content/datasets/interaction-set/Combined/AFBI479.jpg: 352x608 11 Heads, 10 Rears, 528.2ms
# image 418/738 /content/datasets/interaction-set/Combined/AFBI480.jpg: 352x608 8 Heads, 10 Rears, 523.9ms
# image 419/738 /content/datasets/interaction-set/Combined/AFBI481.jpg: 352x608 8 Heads, 10 Rears, 532.0ms
# image 420/738 /content/datasets/interaction-set/Combined/AFBI482.jpg: 352x608 9 Heads, 9 Rears, 527.0ms
# image 421/738 /content/datasets/interaction-set/Combined/AFBI483.jpg: 352x608 8 Heads, 9 Rears, 542.6ms
# image 422/738 /content/datasets/interaction-set/Combined/AFBI484.jpg: 352x608 9 Heads, 9 Rears, 527.4ms
# image 423/738 /content/datasets/interaction-set/Combined/AFBI485.jpg: 352x608 9 Heads, 9 Rears, 533.9ms
# image 424/738 /content/datasets/interaction-set/Combined/AFBI486.jpg: 352x608 9 Heads, 9 Rears, 514.6ms
# image 425/738 /content/datasets/interaction-set/Combined/AFBI488.jpg: 352x608 9 Heads, 9 Rears, 553.0ms
# image 426/738 /content/datasets/interaction-set/Combined/AFBI489.jpg: 352x608 8 Heads, 9 Rears, 884.8ms
# image 427/738 /content/datasets/interaction-set/Combined/AFBI492.jpg: 352x608 9 Heads, 9 Rears, 868.3ms
# image 428/738 /content/datasets/interaction-set/Combined/AFBI493.jpg: 352x608 9 Heads, 9 Rears, 872.5ms
# image 429/738 /content/datasets/interaction-set/Combined/AFBI495.jpg: 352x608 9 Heads, 9 Rears, 707.1ms
# image 430/738 /content/datasets/interaction-set/Combined/AFBI496.jpg: 352x608 8 Heads, 9 Rears, 530.2ms
# image 431/738 /content/datasets/interaction-set/Combined/AFBI497.jpg: 352x608 9 Heads, 9 Rears, 512.9ms
# image 432/738 /content/datasets/interaction-set/Combined/AFBI498.jpg: 352x608 10 Heads, 9 Rears, 534.2ms
# image 433/738 /content/datasets/interaction-set/Combined/AFBI499.jpg: 352x608 9 Heads, 9 Rears, 523.0ms
# image 434/738 /content/datasets/interaction-set/Combined/AUPF001.jpg: 416x608 10 Heads, 12 Rears, 646.4ms
# image 435/738 /content/datasets/interaction-set/Combined/AUPF003.jpg: 416x608 10 Heads, 10 Rears, 644.2ms
# image 436/738 /content/datasets/interaction-set/Combined/AUPF004.jpg: 416x608 10 Heads, 11 Rears, 636.7ms
# image 437/738 /content/datasets/interaction-set/Combined/AUPF005.jpg: 416x608 10 Heads, 10 Rears, 657.4ms
# image 438/738 /content/datasets/interaction-set/Combined/AUPF006.jpg: 416x608 9 Heads, 11 Rears, 646.0ms
# image 439/738 /content/datasets/interaction-set/Combined/AUPF007.jpg: 416x608 9 Heads, 11 Rears, 636.4ms
# image 440/738 /content/datasets/interaction-set/Combined/AUPF008.jpg: 416x608 11 Heads, 11 Rears, 643.7ms
# image 441/738 /content/datasets/interaction-set/Combined/AUPF011.jpg: 416x608 10 Heads, 11 Rears, 632.0ms
# image 442/738 /content/datasets/interaction-set/Combined/AUPF012.jpg: 416x608 10 Heads, 11 Rears, 630.3ms
# image 443/738 /content/datasets/interaction-set/Combined/AUPF013.jpg: 416x608 10 Heads, 11 Rears, 639.0ms
# image 444/738 /content/datasets/interaction-set/Combined/AUPF015.jpg: 416x608 11 Heads, 11 Rears, 634.3ms
# image 445/738 /content/datasets/interaction-set/Combined/AUPF016.jpg: 416x608 9 Heads, 10 Rears, 892.1ms
# image 446/738 /content/datasets/interaction-set/Combined/AUPF017.jpg: 416x608 9 Heads, 11 Rears, 1089.2ms
# image 447/738 /content/datasets/interaction-set/Combined/AUPF018.jpg: 416x608 9 Heads, 11 Rears, 1053.3ms
# image 448/738 /content/datasets/interaction-set/Combined/AUPF019.jpg: 448x608 11 Heads, 8 Rears, 779.1ms
# image 449/738 /content/datasets/interaction-set/Combined/AUPF020.jpg: 448x608 11 Heads, 8 Rears, 687.5ms
# image 450/738 /content/datasets/interaction-set/Combined/AUPF021.jpg: 448x608 10 Heads, 8 Rears, 688.0ms
# image 451/738 /content/datasets/interaction-set/Combined/AUPF022.jpg: 448x608 9 Heads, 10 Rears, 680.9ms
# image 452/738 /content/datasets/interaction-set/Combined/AUPF023.jpg: 448x608 8 Heads, 9 Rears, 687.4ms
# ...
# image 589/738 /content/datasets/interaction-set/Combined/AUPF225.jpg: 416x608 16 Heads, 16 Rears, 650.1ms
# image 590/738 /content/datasets/interaction-set/Combined/AUPF227.jpg: 416x608 15 Heads, 17 Rears, 942.2ms
# image 591/738 /content/datasets/interaction-set/Combined/AUPF228.jpg: 384x608 13 Heads, 14 Rears, 977.3ms
# image 592/738 /content/datasets/interaction-set/Combined/AUPF229.jpg: 384x608 11 Heads, 17 Rears, 984.4ms
# image 593/738 /content/datasets/interaction-set/Combined/AUPF230.jpg: 384x608 11 Heads, 16 Rears, 712.8ms
# image 594/738 /content/datasets/interaction-set/Combined/AUPF231.jpg: 384x608 13 Heads, 16 Rears, 600.4ms
# image 595/738 /content/datasets/interaction-set/Combined/AUPF233.jpg: 384x608 13 Heads, 17 Rears, 585.6ms
# image 596/738 /content/datasets/interaction-set/Combined/AUPF238.jpg: 384x608 13 Heads, 19 Rears, 602.2ms
# image 597/738 /content/datasets/interaction-set/Combined/AUPF239.jpg: 384x608 14 Heads, 17 Rears, 595.1ms
# image 598/738 /content/datasets/interaction-set/Combined/AUPF240.jpg: 384x608 15 Heads, 17 Rears, 584.8ms
# image 599/738 /content/datasets/interaction-set/Combined/AUPF241.jpg: 384x608 15 Heads, 17 Rears, 590.2ms
# image 600/738 /content/datasets/interaction-set/Combined/AUPF242.jpg: 384x608 14 Heads, 18 Rears, 586.4ms
# image 601/738 /content/datasets/interaction-set/Combined/AUPF243.jpg: 384x608 14 Heads, 16 Rears, 607.0ms
# image 602/738 /content/datasets/interaction-set/Combined/AUPF245.jpg: 384x608 16 Heads, 15 Rears, 598.1ms
# image 603/738 /content/datasets/interaction-set/Combined/AUPF246.jpg: 384x608 14 Heads, 16 Rears, 596.2ms
# image 604/738 /content/datasets/interaction-set/Combined/AUPF247.jpg: 416x608 14 Heads, 18 Rears, 652.7ms
# image 605/738 /content/datasets/interaction-set/Combined/AUPF248.jpg: 416x608 14 Heads, 22 Rears, 641.5ms
# image 606/738 /content/datasets/interaction-set/Combined/AUPF249.jpg: 416x608 16 Heads, 18 Rears, 637.2ms
# image 607/738 /content/datasets/interaction-set/Combined/AUPF250.jpg: 416x608 14 Heads, 20 Rears, 646.5ms
# image 608/738 /content/datasets/interaction-set/Combined/AUPF252.jpg: 416x608 12 Heads, 18 Rears, 650.6ms
# image 609/738 /content/datasets/interaction-set/Combined/AUPF253.jpg: 416x608 14 Heads, 16 Rears, 1079.6ms
# image 610/738 /content/datasets/interaction-set/Combined/AUPF255.jpg: 416x608 17 Heads, 17 Rears, 1054.3ms
# image 611/738 /content/datasets/interaction-set/Combined/AUPF256.jpg: 416x608 17 Heads, 18 Rears, 996.5ms
# image 612/738 /content/datasets/interaction-set/Combined/AUPF257.jpg: 416x608 17 Heads, 16 Rears, 631.8ms
# image 613/738 /content/datasets/interaction-set/Combined/AUPF259.jpg: 416x608 16 Heads, 17 Rears, 652.2ms
# image 614/738 /content/datasets/interaction-set/Combined/AUPF260.jpg: 416x608 14 Heads, 18 Rears, 642.2ms
# image 615/738 /content/datasets/interaction-set/Combined/AUPF261.jpg: 416x608 14 Heads, 15 Rears, 630.6ms
# image 616/738 /content/datasets/interaction-set/Combined/AUPF265.jpg: 416x608 15 Heads, 16 Rears, 660.9ms
# image 617/738 /content/datasets/interaction-set/Combined/AUPF266.jpg: 448x608 8 Heads, 9 Rears, 682.9ms
# image 618/738 /content/datasets/interaction-set/Combined/AUPF267.jpg: 448x608 10 Heads, 9 Rears, 681.8ms
# image 619/738 /content/datasets/interaction-set/Combined/AUPF268.jpg: 448x608 10 Heads, 8 Rears, 698.6ms
# image 620/738 /content/datasets/interaction-set/Combined/AUPF269.jpg: 448x608 8 Heads, 7 Rears, 690.1ms
# image 621/738 /content/datasets/interaction-set/Combined/AUPF270.jpg: 448x608 9 Heads, 7 Rears, 679.9ms
# image 622/738 /content/datasets/interaction-set/Combined/AUPF271.jpg: 448x608 8 Heads, 8 Rears, 692.3ms
# image 623/738 /content/datasets/interaction-set/Combined/AUPF272.jpg: 448x608 9 Heads, 10 Rears, 684.7ms
# image 624/738 /content/datasets/interaction-set/Combined/AUPF274.jpg: 448x608 8 Heads, 8 Rears, 688.6ms
# image 625/738 /content/datasets/interaction-set/Combined/AUPF275.jpg: 448x608 9 Heads, 7 Rears, 679.3ms
# image 626/738 /content/datasets/interaction-set/Combined/AUPF276.jpg: 448x608 9 Heads, 6 Rears, 1011.5ms
# image 627/738 /content/datasets/interaction-set/Combined/AUPF277.jpg: 448x608 10 Heads, 8 Rears, 1155.4ms
# image 628/738 /content/datasets/interaction-set/Combined/AUPF278.jpg: 448x608 9 Heads, 8 Rears, 1115.1ms
# image 629/738 /content/datasets/interaction-set/Combined/AUPF279.jpg: 448x608 8 Heads, 9 Rears, 705.3ms
# image 630/738 /content/datasets/interaction-set/Combined/AUPF282.jpg: 448x608 8 Heads, 9 Rears, 697.8ms
# image 631/738 /content/datasets/interaction-set/Combined/AUPF283.jpg: 448x608 6 Heads, 9 Rears, 695.3ms
# image 632/738 /content/datasets/interaction-set/Combined/AUPF284.jpg: 448x608 6 Heads, 10 Rears, 691.1ms
# image 633/738 /content/datasets/interaction-set/Combined/AUPF285.jpg: 448x608 8 Heads, 9 Rears, 710.4ms
# image 634/738 /content/datasets/interaction-set/Combined/AUPF286.jpg: 448x608 9 Heads, 9 Rears, 698.6ms
# image 635/738 /content/datasets/interaction-set/Combined/AUPF287.jpg: 448x608 7 Heads, 8 Rears, 704.8ms
# image 636/738 /content/datasets/interaction-set/Combined/AUPF288.jpg: 448x608 6 Heads, 10 Rears, 703.9ms
# image 637/738 /content/datasets/interaction-set/Combined/AUPF289.jpg: 448x608 9 Heads, 8 Rears, 697.0ms
# image 638/738 /content/datasets/interaction-set/Combined/AUPF291.jpg: 448x608 10 Heads, 9 Rears, 702.0ms
# image 639/738 /content/datasets/interaction-set/Combined/AUPF292.jpg: 448x608 10 Heads, 9 Rears, 692.5ms
# image 640/738 /content/datasets/interaction-set/Combined/AUPF293.jpg: 448x608 10 Heads, 9 Rears, 695.6ms
# image 641/738 /content/datasets/interaction-set/Combined/AUPF295.jpg: 448x608 9 Heads, 10 Rears, 698.2ms
# image 642/738 /content/datasets/interaction-set/Combined/AUPF296.jpg: 448x608 10 Heads, 9 Rears, 723.1ms
# image 643/738 /content/datasets/interaction-set/Combined/AUPF297.jpg: 448x608 8 Heads, 8 Rears, 1163.2ms
# image 644/738 /content/datasets/interaction-set/Combined/AUPF298.jpg: 448x608 9 Heads, 9 Rears, 1152.1ms
# image 645/738 /content/datasets/interaction-set/Combined/AUPF299.jpg: 448x608 9 Heads, 8 Rears, 994.9ms
# image 646/738 /content/datasets/interaction-set/Combined/AUPF302.jpg: 448x608 10 Heads, 7 Rears, 698.6ms
# image 647/738 /content/datasets/interaction-set/Combined/AUPF303.jpg: 448x608 10 Heads, 6 Rears, 698.3ms
# image 648/738 /content/datasets/interaction-set/Combined/AUPF304.jpg: 448x608 8 Heads, 9 Rears, 698.1ms
# image 649/738 /content/datasets/interaction-set/Combined/AUPF305.jpg: 448x608 8 Heads, 8 Rears, 700.0ms
# image 650/738 /content/datasets/interaction-set/Combined/AUPF306.jpg: 448x608 11 Heads, 9 Rears, 696.6ms
# image 651/738 /content/datasets/interaction-set/Combined/AUPF309.jpg: 448x608 12 Heads, 11 Rears, 716.1ms
# image 652/738 /content/datasets/interaction-set/Combined/AUPF310.jpg: 448x608 8 Heads, 11 Rears, 695.4ms
# image 653/738 /content/datasets/interaction-set/Combined/AUPF312.jpg: 448x608 10 Heads, 9 Rears, 686.3ms
# image 654/738 /content/datasets/interaction-set/Combined/AUPF315.jpg: 448x608 10 Heads, 10 Rears, 702.1ms
# image 655/738 /content/datasets/interaction-set/Combined/AUPF316.jpg: 448x608 7 Heads, 8 Rears, 698.0ms
# image 656/738 /content/datasets/interaction-set/Combined/AUPF320.jpg: 448x608 9 Heads, 11 Rears, 718.1ms
# image 657/738 /content/datasets/interaction-set/Combined/AUPF321.jpg: 448x608 10 Heads, 10 Rears, 689.3ms
# image 658/738 /content/datasets/interaction-set/Combined/AUPF329.jpg: 448x608 10 Heads, 10 Rears, 690.2ms
# image 659/738 /content/datasets/interaction-set/Combined/AUPF331.jpg: 448x608 11 Heads, 11 Rears, 870.1ms
# image 660/738 /content/datasets/interaction-set/Combined/AUPF334.jpg: 448x608 10 Heads, 10 Rears, 1147.0ms
# image 661/738 /content/datasets/interaction-set/Combined/AUPF336.jpg: 448x608 9 Heads, 13 Rears, 1129.1ms
# image 662/738 /content/datasets/interaction-set/Combined/AUPF342.jpg: 448x608 11 Heads, 10 Rears, 826.0ms
# image 663/738 /content/datasets/interaction-set/Combined/AUPF347.jpg: 448x608 10 Heads, 11 Rears, 683.0ms
# image 664/738 /content/datasets/interaction-set/Combined/AUPF349.jpg: 448x608 11 Heads, 10 Rears, 697.2ms
# image 665/738 /content/datasets/interaction-set/Combined/AUPF354.jpg: 448x608 10 Heads, 10 Rears, 688.5ms
# image 666/738 /content/datasets/interaction-set/Combined/AUPF355.jpg: 448x608 9 Heads, 10 Rears, 698.6ms
# image 667/738 /content/datasets/interaction-set/Combined/AUPF356.jpg: 448x608 8 Heads, 8 Rears, 689.2ms
# image 668/738 /content/datasets/interaction-set/Combined/AUPF357.jpg: 448x608 4 Heads, 9 Rears, 684.2ms
# image 669/738 /content/datasets/interaction-set/Combined/AUPF358.jpg: 448x608 8 Heads, 7 Rears, 707.1ms
# image 670/738 /content/datasets/interaction-set/Combined/AUPF359.jpg: 448x608 7 Heads, 7 Rears, 693.9ms
# image 671/738 /content/datasets/interaction-set/Combined/AUPF361.jpg: 448x608 9 Heads, 13 Rears, 707.0ms
# image 672/738 /content/datasets/interaction-set/Combined/AUPF362.jpg: 448x608 10 Heads, 11 Rears, 689.5ms
# image 673/738 /content/datasets/interaction-set/Combined/AUPF363.jpg: 448x608 11 Heads, 10 Rears, 699.9ms
# image 674/738 /content/datasets/interaction-set/Combined/AUPF364.jpg: 448x608 10 Heads, 12 Rears, 686.4ms
# image 675/738 /content/datasets/interaction-set/Combined/AUPF366.jpg: 448x608 8 Heads, 12 Rears, 694.3ms
# image 676/738 /content/datasets/interaction-set/Combined/AUPF368.jpg: 448x608 10 Heads, 12 Rears, 1021.0ms
# image 677/738 /content/datasets/interaction-set/Combined/AUPF369.jpg: 448x608 10 Heads, 11 Rears, 1125.5ms
# image 678/738 /content/datasets/interaction-set/Combined/AUPF374.jpg: 448x608 10 Heads, 10 Rears, 1100.6ms
# image 679/738 /content/datasets/interaction-set/Combined/AUPF376.jpg: 448x608 10 Heads, 10 Rears, 730.7ms
# image 680/738 /content/datasets/interaction-set/Combined/AUPF378.jpg: 448x608 10 Heads, 9 Rears, 689.7ms
# image 681/738 /content/datasets/interaction-set/Combined/AUPF380.jpg: 448x608 11 Heads, 8 Rears, 685.5ms
# image 682/738 /content/datasets/interaction-set/Combined/AUPF381.jpg: 448x608 9 Heads, 9 Rears, 698.6ms
# image 683/738 /content/datasets/interaction-set/Combined/AUPF382.jpg: 448x608 8 Heads, 9 Rears, 688.9ms
# image 684/738 /content/datasets/interaction-set/Combined/AUPF383.jpg: 448x608 9 Heads, 9 Rears, 688.4ms
# image 685/738 /content/datasets/interaction-set/Combined/AUPF384.jpg: 448x608 8 Heads, 9 Rears, 706.6ms
# image 686/738 /content/datasets/interaction-set/Combined/AUPF387.jpg: 448x608 6 Heads, 7 Rears, 692.0ms
# image 687/738 /content/datasets/interaction-set/Combined/AUPF388.jpg: 448x608 11 Heads, 10 Rears, 705.4ms
# image 688/738 /content/datasets/interaction-set/Combined/AUPF395.jpg: 448x608 9 Heads, 14 Rears, 679.4ms
# image 689/738 /content/datasets/interaction-set/Combined/AUPF399.jpg: 448x608 8 Heads, 10 Rears, 684.6ms
# image 690/738 /content/datasets/interaction-set/Combined/AUPF402.jpg: 448x608 10 Heads, 11 Rears, 693.4ms
# image 691/738 /content/datasets/interaction-set/Combined/AUPF403.jpg: 448x608 10 Heads, 9 Rears, 678.4ms
# image 692/738 /content/datasets/interaction-set/Combined/AUPF405.jpg: 448x608 11 Heads, 9 Rears, 691.8ms
# image 693/738 /content/datasets/interaction-set/Combined/AUPF407.jpg: 448x608 9 Heads, 10 Rears, 1121.1ms
# image 694/738 /content/datasets/interaction-set/Combined/AUPF408.jpg: 448x608 12 Heads, 10 Rears, 1137.1ms
# image 695/738 /content/datasets/interaction-set/Combined/AUPF409.jpg: 448x608 10 Heads, 10 Rears, 1019.3ms
# image 696/738 /content/datasets/interaction-set/Combined/AUPF410.jpg: 448x608 10 Heads, 8 Rears, 694.5ms
# image 697/738 /content/datasets/interaction-set/Combined/AUPF412.jpg: 448x608 10 Heads, 9 Rears, 698.0ms
# image 698/738 /content/datasets/interaction-set/Combined/AUPF413.jpg: 448x608 10 Heads, 11 Rears, 683.7ms
# image 699/738 /content/datasets/interaction-set/Combined/AUPF414.jpg: 448x608 9 Heads, 11 Rears, 695.6ms
# image 700/738 /content/datasets/interaction-set/Combined/AUPF415.jpg: 448x608 9 Heads, 9 Rears, 694.7ms
# image 701/738 /content/datasets/interaction-set/Combined/AUPF417.jpg: 448x608 9 Heads, 9 Rears, 680.9ms
# image 702/738 /content/datasets/interaction-set/Combined/AUPF418.jpg: 448x608 12 Heads, 8 Rears, 692.9ms
# image 703/738 /content/datasets/interaction-set/Combined/AUPF422.jpg: 448x608 9 Heads, 10 Rears, 689.7ms
# image 704/738 /content/datasets/interaction-set/Combined/AUPF425.jpg: 448x608 10 Heads, 11 Rears, 695.3ms
# image 705/738 /content/datasets/interaction-set/Combined/AUPF428.jpg: 448x608 10 Heads, 9 Rears, 683.0ms
# image 706/738 /content/datasets/interaction-set/Combined/AUPF430.jpg: 448x608 11 Heads, 8 Rears, 697.1ms
# image 707/738 /content/datasets/interaction-set/Combined/AUPF434.jpg: 448x608 11 Heads, 9 Rears, 700.0ms
# image 708/738 /content/datasets/interaction-set/Combined/AUPF448.jpg: 448x608 11 Heads, 10 Rears, 692.1ms
# image 709/738 /content/datasets/interaction-set/Combined/AUPF449.jpg: 448x608 10 Heads, 12 Rears, 780.4ms
# image 710/738 /content/datasets/interaction-set/Combined/AUPF453.jpg: 448x608 10 Heads, 10 Rears, 1155.6ms
# image 711/738 /content/datasets/interaction-set/Combined/AUPF456.jpg: 448x608 12 Heads, 10 Rears, 1160.1ms
# image 712/738 /content/datasets/interaction-set/Combined/AUPF457.jpg: 448x608 11 Heads, 10 Rears, 922.6ms
# image 713/738 /content/datasets/interaction-set/Combined/AUPF458.jpg: 448x608 11 Heads, 10 Rears, 713.2ms
# image 714/738 /content/datasets/interaction-set/Combined/AUPF461.jpg: 448x608 12 Heads, 9 Rears, 699.2ms
# image 715/738 /content/datasets/interaction-set/Combined/AUPF462.jpg: 448x608 10 Heads, 10 Rears, 688.4ms
# image 716/738 /content/datasets/interaction-set/Combined/AUPF463.jpg: 448x608 9 Heads, 10 Rears, 689.0ms
# image 717/738 /content/datasets/interaction-set/Combined/AUPF468.jpg: 448x608 10 Heads, 11 Rears, 689.7ms
# image 718/738 /content/datasets/interaction-set/Combined/AUPF469.jpg: 448x608 10 Heads, 10 Rears, 691.1ms
# image 719/738 /content/datasets/interaction-set/Combined/AUPF470.jpg: 448x608 10 Heads, 11 Rears, 683.3ms
# image 720/738 /content/datasets/interaction-set/Combined/AUPF472.jpg: 448x608 9 Heads, 11 Rears, 694.5ms
# image 721/738 /content/datasets/interaction-set/Combined/AUPF475.jpg: 448x608 9 Heads, 10 Rears, 696.6ms
# image 722/738 /content/datasets/interaction-set/Combined/AUPF476.jpg: 448x608 12 Heads, 10 Rears, 686.4ms
# image 723/738 /content/datasets/interaction-set/Combined/AUPF477.jpg: 448x608 9 Heads, 9 Rears, 695.4ms
# image 724/738 /content/datasets/interaction-set/Combined/AUPF481.jpg: 448x608 10 Heads, 7 Rears, 675.2ms
# image 725/738 /content/datasets/interaction-set/Combined/AUPF483.jpg: 448x608 9 Heads, 9 Rears, 684.9ms
# image 726/738 /content/datasets/interaction-set/Combined/AUPF484.jpg: 448x608 9 Heads, 10 Rears, 893.4ms
# image 727/738 /content/datasets/interaction-set/Combined/AUPF485.jpg: 448x608 12 Heads, 9 Rears, 1156.2ms
# image 728/738 /content/datasets/interaction-set/Combined/AUPF486.jpg: 448x608 11 Heads, 10 Rears, 1125.2ms
# image 729/738 /content/datasets/interaction-set/Combined/AUPF487.jpg: 448x608 10 Heads, 8 Rears, 768.6ms
# image 730/738 /content/datasets/interaction-set/Combined/AUPF490.jpg: 448x608 10 Heads, 10 Rears, 690.0ms
# image 731/738 /content/datasets/interaction-set/Combined/AUPF491.jpg: 448x608 8 Heads, 12 Rears, 692.8ms
# image 732/738 /content/datasets/interaction-set/Combined/AUPF492.jpg: 448x608 10 Heads, 9 Rears, 673.7ms
# image 733/738 /content/datasets/interaction-set/Combined/AUPF493.jpg: 448x608 7 Heads, 9 Rears, 684.0ms
# image 734/738 /content/datasets/interaction-set/Combined/AUPF494.jpg: 448x608 10 Heads, 9 Rears, 689.7ms
# image 735/738 /content/datasets/interaction-set/Combined/AUPF495.jpg: 448x608 6 Heads, 9 Rears, 684.4ms
# image 736/738 /content/datasets/interaction-set/Combined/AUPF497.jpg: 448x608 8 Heads, 7 Rears, 687.1ms
# image 737/738 /content/datasets/interaction-set/Combined/AUPF499.jpg: 448x608 10 Heads, 9 Rears, 692.8ms
# image 738/738 /content/datasets/interaction-set/Combined/AUPF500.jpg: 448x608 9 Heads, 8 Rears, 695.2ms
# Speed: 0.8ms pre-process, 642.8ms inference, 1.0ms NMS per image at shape (1, 3, 608, 608)
# Results saved to runs/detect/exp2

# %% [markdown]
# **This is the detect implementation in the website (img size can be adjusted)**

# %%
path_hubconfig = '/content/YOLOv5-Modification'
path_weightfile = '/content/YOLOv5-Modification/best-weights/test.pt'

# %%
import torch
import os

model = torch.hub.load(path_hubconfig, 'custom',
                     path=path_weightfile, source='local',)

jpg_files = []

for filename in os.listdir(Combined_path):
    if filename.endswith(".jpg"):
        file_path = os.path.join(Combined_path, filename)
        jpg_files.append(file_path)
# print(jpg_files)
# print(len(jpg_files))

results_torch = model(jpg_files, size=600)
results_torch.print()
# Out:
# YOLOv5 🚀 539e7e9 Python-3.10.11 torch-2.0.0+cu118 CPU
# requirements: /content/requirements.txt not found, check failed.
# Fusing layers...
# custom_YOLOv5m summary: 212 layers, 20856975 parameters, 0 gradients
# Adding AutoShape...

# %%
# sample df of bounding-box csv
# %cd /content/YOLOv5-Modification
import pandas as pd

df = pd.read_csv('test.csv')
df
# Out:
# /content/YOLOv5-Modification
#      Image_Name  Confidence Score Object_Name  Class_Index  minX  maxX  minY  \
# 0   AFBI001.jpg          0.315416        Head            0   252   296   350
# 1   AFBI001.jpg          0.508910        Head            0   248   297   343
# 2   AFBI001.jpg          0.527385        Rear            1   286   330   349
# 3   AFBI001.jpg          0.529184        Head            0   309   351   217
# 4   AFBI001.jpg          0.633693        Rear            1   281   328   319
# 5   AFBI001.jpg          0.665945        Head            0   245   292   378
# 6   AFBI001.jpg          0.675250        Head            0   530   572   308
# 7   AFBI002.jpg          0.679245        Rear            1    91   136   305
# 8   AFBI002.jpg          0.692774        Rear            1   120   157   335
# 9   AFBI002.jpg          0.733357        Rear            1   650   696   282
# 10  AFBI002.jpg          0.741534        Rear            1   358   401   358
# 11  AFBI002.jpg          0.748507        Head            0   226   268   249
# 12  AFBI002.jpg          0.758693        Head            0   107   146   183
# 13  AFBI002.jpg          0.761583        Rear            1   288   332   162
# 14  AFBI002.jpg          0.769910        Head            0    99   136   224
# 15  AFBI002.jpg          0.774928        Rear            1   194   236   166
#
#     maxY
# 0    408
# 1    380
# 2    387
# 3    266
# 4    349
# 5    408
# 6    349
# 7    333
# 8    370
# 9    324
# 10   403
# 11   287
# 12   215
# 13   189
# 14   256
# 15   204

# %% [markdown]
# **This is the Interaction Method (detect.py)**

# %%
# %cd /content/YOLOv5-Modification
import pandas as pd
import os

df = pd.read_csv('bounding-boxes.csv')

# variables
iou_threshold = 0.05

# df results
results_df = pd.DataFrame(columns=['Image_Name', 'Classification', 'Interaction_Count'])

def compute_interactions(data, threshold, results):
    # unique image names
    image_names = data['Image_Name'].unique()

    # loop for each unique name
    for name in image_names:
      # interaction variables
      interaction_flag = False
      interaction_count = 0

      # subset dataframe with this image name
      name_df = data[data['Image_Name'] == name]

      # subset dataframes of heads and rears
      head_df = name_df[name_df['Object_Name'] == 'Head'].reset_index(drop=True)
      rear_df = name_df[name_df['Object_Name'] == 'Rear'].reset_index(drop=True)

      # loop over heads and rears in the image
      for i, head_row in head_df.iterrows():
        for j, rear_row in rear_df.iterrows():
            # bounding box indexing
            # df[4] = minX, df[5] = maxX, df[6] = minY, df[7] = maxY

            head_minX = head_df.iloc[i, 4]
            head_maxX = head_df.iloc[i, 5]
            head_minY = head_df.iloc[i, 6]
            head_maxY = head_df.iloc[i, 7]

            rear_minX = rear_df.iloc[j, 4]
            rear_maxX = rear_df.iloc[j, 5]
            rear_minY = rear_df.iloc[j, 6]
            rear_maxY = rear_df.iloc[j, 7]

            # this is for the headBox and rearBox
            curr_iou = compute_iou(head_minX, head_maxX, head_minY, head_maxY,
                        rear_minX, rear_maxX, rear_minY, rear_maxY)
            
            # print("computed the IoU:", curr_iou)

            if (curr_iou >= threshold):
              interaction_flag = True
              interaction_count += 1

            # # tester
            # print(i, j)
            # print(head_minX, head_minY, head_maxX, head_maxY)
            # print(rear_minX, rear_minY, rear_maxX, rear_maxY)

      temp_list = [name, 
                   1 if interaction_flag else 0, 
                   interaction_count]
      results.loc[len(results)] = temp_list
    return results

def compute_iou(head_minX, head_maxX, head_minY, head_maxY, rear_minX, rear_maxX, rear_minY, rear_maxY):
    # determine (x,y) coordinates of the intersection rectangle
    x_left = max(head_minX, rear_minX)
    y_top = max(head_minY, rear_minY)
    x_right = min(head_maxX, rear_maxX)
    y_bottom = min(head_maxY, rear_maxY)

    # compute the area of intersection rectangle
    intersection_area = max(0, x_right - x_left + 1) * max(0, y_bottom - y_top + 1)

    # compute area of both prediction and ground-truth
    # rectangles
    headArea = (head_maxX - head_minX + 1) * (head_maxY - head_minY + 1)
    rearArea = (rear_maxX - rear_minX + 1) * (rear_maxY - rear_minY + 1)
    union_area = float(headArea + rearArea - intersection_area)

    # compute IoU
    iou = intersection_area / union_area
    return iou

res = compute_interactions(df, iou_threshold, results_df).copy()
if os.path.exists('results.csv'):
    os.remove('results.csv')
res.to_csv('results.csv', index=False)

# print(res)
# Out:
# /content/YOLOv5-Modification

# %% [markdown]
# **This is Interaction Method (PyTorch)**

# %%
# %cd /content/YOLOv5-Modification
import pandas as pd
import os

# df format [xmin ymin xmax ymax confidence class name]
bb = results_torch.pandas().xyxy

# variables
iou_threshold = 0.05

# df results
results_df = pd.DataFrame(columns=['Image_Name', 'Classification', 'Interaction_Count'])

def compute_interactions(data, threshold, results):
    # unique image names
    image_names = data['name'].unique()

    # loop for each unique name
    for name in image_names:
      # interaction variables
      interaction_flag = False
      interaction_count = 0

      # subset dataframe with this image name
      name_df = data[data['name'] == name]

      # subset dataframes of heads and rears
      head_df = name_df[name_df['name'] == 'Head'].reset_index(drop=True)
      rear_df = name_df[name_df['name'] == 'Rear'].reset_index(drop=True)

      # loop over heads and rears in the image
      for i, head_row in head_df.iterrows():
        for j, rear_row in rear_df.iterrows():
            # bounding box indexing
            # df[0] = minX, df[1] = minY, df[2] = maxX, df[3] = maxY

            head_minX = head_df.iloc[i, 0]
            head_minY = head_df.iloc[i, 1]
            head_maxX = head_df.iloc[i, 2]
            head_maxY = head_df.iloc[i, 3]

            rear_minX = rear_df.iloc[j, 0]
            rear_minY = rear_df.iloc[j, 1]
            rear_maxX = rear_df.iloc[j, 2]
            rear_maxY = rear_df.iloc[j, 3]

            # this is for the headBox and rearBox
            curr_iou = compute_iou(head_minX, head_maxX, head_minY, head_maxY,
                        rear_minX, rear_maxX, rear_minY, rear_maxY)
            
            # print("computed the IoU:", curr_iou)

            if (curr_iou >= threshold):
              interaction_flag = True
              interaction_count += 1

            # # tester
            # print(i, j)
            # print(head_minX, head_minY, head_maxX, head_maxY)
            # print(rear_minX, rear_minY, rear_maxX, rear_maxY)

      temp_list = [name, 
                   1 if interaction_flag else 0, 
                   interaction_count]
      results.loc[len(results)] = temp_list
    return results

def compute_iou(head_minX, head_maxX, head_minY, head_maxY, rear_minX, rear_maxX, rear_minY, rear_maxY):
    # determine (x,y) coordinates of the intersection rectangle
    x_left = max(head_minX, rear_minX)
    y_top = max(head_minY, rear_minY)
    x_right = min(head_maxX, rear_maxX)
    y_bottom = min(head_maxY, rear_maxY)

    # compute the area of intersection rectangle
    intersection_area = max(0, x_right - x_left + 1) * max(0, y_bottom - y_top + 1)

    # compute area of both prediction and ground-truth
    # rectangles
    headArea = (head_maxX - head_minX + 1) * (head_maxY - head_minY + 1)
    rearArea = (rear_maxX - rear_minX + 1) * (rear_maxY - rear_minY + 1)
    union_area = float(headArea + rearArea - intersection_area)

    # compute IoU
    iou = intersection_area / union_area
    return iou

res = compute_interactions(bb, iou_threshold, results_df).copy()
if os.path.exists('results.csv'):
    os.remove('results.csv')
res.to_csv('results.csv', index=False)

# %% [markdown]
# ## Evaluations

# %% [markdown]
# **Getting and Processing Necessary Data**

# %%
# if os.path.exists(Combined_csv_path):
#     os.remove(Combined_csv_path)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# True Values
truth_df = pd.read_csv(Combined_csv_path)
# Changing column names, removing extra \', binarizing the classification
binarize = lambda x: 0 if x == 0 else 1

truth_df['Image_Name'] = truth_df['Image_Name'].str.replace('\'', '')
truth_df['Classification'] = truth_df['Classification'].apply(binarize)

# truth_df

# %%
# Getting truth_df counts
truth_df['is_AFBI'] = truth_df['Image_Name'].str.contains('AFBI').astype(int)
truth_df['is_AUF'] = truth_df['Image_Name'].str.contains('AUPF').astype(int)
AFBI_grouped = truth_df.groupby('is_AFBI')
# AUF_grouped = truth_df.groupby('is_AUF')

# This creates separated dfs for the two data sets
for name, group in AFBI_grouped:
    df_name = 'AFBI_group_df' if name else 'AUF_group_df'
    globals()[df_name] = group.copy()

truth = truth_df['Classification'].value_counts()
afbi = AFBI_group_df['Classification'].value_counts()
auf = AUF_group_df['Classification'].value_counts()
print("truth:\n", truth,'\n',"afbi:\n",afbi,'\n'," auf:\n",auf,'\n')
# Out:
# truth:
#  0    456
# 1    282
# Name: Classification, dtype: int64
#  afbi:
#  0    322
# 1    111
# Name: Classification, dtype: int64
#   auf:
#  1    171
# 0    134
# Name: Classification, dtype: int64

# %%
# Predicted Values
pred_df = pd.read_csv('results.csv')
# pred_df

# %%
# Getting pred_df counts
pred_df['is_AFBI'] = pred_df['Image_Name'].str.contains('AFBI').astype(int)
pred_df['is_AUF'] = pred_df['Image_Name'].str.contains('AUPF').astype(int)
AFBI_grouped = pred_df.groupby('is_AFBI')

# AUF_grouped = truth_df.groupby('is_AUF')

# This creates separated dfs for the two data sets
for name, group in AFBI_grouped:
    df_name = 'AFBI_group_df' if name else 'AUF_group_df'
    globals()[df_name] = group.copy()

pred = pred_df['Classification'].value_counts()
afbi = AFBI_group_df['Classification'].value_counts()
auf = AUF_group_df['Classification'].value_counts()
print("pred:\n", pred,'\n',"afbi:\n",afbi,'\n'," auf:\n",auf,'\n')
# Out:
# pred:
#  1    399
# 0    339
# Name: Classification, dtype: int64
#  afbi:
#  0    225
# 1    208
# Name: Classification, dtype: int64
#   auf:
#  1    191
# 0    114
# Name: Classification, dtype: int64

# %% [markdown]
# **Evalution Proper**

# %%
print(truth_df.shape[0],
      pred_df.shape[0])
# Out:
# 738 738

# %%
y_true = truth_df["Classification"]
y_pred = pred_df["Classification"]

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
confusion_matrix = confusion_matrix(y_true, y_pred)
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", confusion_matrix)
# Out:
# Accuracy: 0.7249322493224932
# Precision: 0.5989974937343359
# Recall: 0.8475177304964538
# F1 Score: 0.7019089574155654
# Confusion Matrix:
#  [[296 160]
#  [ 43 239]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# assume y_true and y_pred are the true and predicted labels
cm = confusion_matrix(y_true, y_pred)

# create a heatmap using seaborn
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d")

# add axis labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

# show the plot
plt.show()
