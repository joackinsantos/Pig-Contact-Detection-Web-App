# %% [markdown]
# <a href="https://colab.research.google.com/github/joackinsantos/Pig-Contact-Detection-Web-App/blob/main/Pig_SP_Notebook_Interaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pig Contact Detection System Using Convolutional Neural Networks
# **For Detection, it uses YOLOv5 with CSPDarknet as the backbone**<br>
# **For Interaction, it compares the IoU between the head and rear boxes  and a calibrated interaction threshold**<br>
#
# _Notebook by Joackin Santos_
#
# **Main Notebook:**
# https://colab.research.google.com/drive/1orWlSQr0xjVmVI-2SvIuBQiu3wvIgBS3?usp=sharing
#
# This is the accompanying notebook for the Pig Contact Detection System. This notebook uses the weights (*.pt) from the trained models to output the coordinates of the bounding boxes from detect.py of YOLOv5. The output is used to get the IoU (Intersection over Union) of the heads and rears in an image. This will be used to compute for interaction, based on a calibrated IoU threshold.
#
# This will use the AFBI and AUF datasets to get predictions and truth values (annotated) to evaluate the interaction method.
#
# Upon evaluation of the best threshold, the method will be extracted for single image use, to be integrated to the website application.

# %% [markdown]
# ## Setup

# %%
# for folder deletions
import shutil
shutil.rmtree('/content/YOLOv5-Modification')

# %% [markdown]
# **Cloning Repositories**

# %%
# clone repository containing yolov5 and datasets
# rename pig-datasets repo to datasets for yolov5
# %cd /content
# !git clone -b interaction-method https://github.com/joackinsantos/YOLOv5-Modification
# !git clone https://github.com/joackinsantos/pig-datasets datasets
# Out:
# /content
# Cloning into 'YOLOv5-Modification'...
# remote: Enumerating objects: 9895, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 9895 (delta 41), reused 79 (delta 35), pack-reused 9808
# Receiving objects: 100% (9895/9895), 475.52 MiB | 23.79 MiB/s, done.
# Resolving deltas: 100% (125/125), done.
# Updating files: 100% (162/162), done.
# Cloning into 'datasets'...
# remote: Enumerating objects: 54055, done.
# remote: Counting objects: 100% (9623/9623), done.
# remote: Compressing objects: 100% (9616/9616), done.
# remote: Total 54055 (delta 7), reused 9623 (delta 7), pack-reused 44432
# Receiving objects: 100% (54055/54055), 1.21 GiB | 20.08 MiB/s, done.
# Resolving deltas: 100% (60/60), done.
# Updating files: 100% (59989/59989), done.

# %% [markdown]
# **Data Paths**

# %%
# resource paths
AFBI_path = '/content/datasets/interaction-set/AFBI'
AUF_path = '/content/datasets/interaction-set/AUF'
Combined_path = '/content/datasets/interaction-set/Combined'
Combined_csv_path = '/content/datasets/interaction-set/Combined.csv'
img_AFBI_path = '/content/datasets/interaction-set/AFBI/AFBI001.jpg'
img_AUF_path = '/content/datasets/interaction-set/AUF/AUPF190.jpg'
weight_path = '/content/YOLOv5-Modification/test-weights/'

# %%
# %ls
# Out:
# datasets/  sample_data/  YOLOv5-Modification/

# %% [markdown]
# **Detection**
# *detect.py was modified to extract bounding box properties such as:*
# - image names
# - confidence scores
# - classfication and class index
# - minX, minY, maxX, maxY <br>
#
# This is exported as the "bounding-boxes.csv" file

# %% [markdown]
# **This uses the detect.py from YOLOv5 ultralytics repository**

# %%
# %cd /content/YOLOv5-Modification
# !python detect.py --img 600 --weights {weight_path}/test.pt --source {Combined_path}

# %% [markdown]
# **This is the detect implementation in the website (img size can be adjusted)**

# %%
# pytorch setup
# %cd /content
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
torch.cuda.empty_cache()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))

# %%
path_hubconfig = '/content/YOLOv5-Modification'
path_weightfile = '/content/YOLOv5-Modification/best-weights/aug_midNBG_m_600_8_100.pt'

# %%
import torch
import os

img_size = 500

img_AFBI_path = '/content/datasets/interaction-set/AFBI/AFBI001.jpg'
img_AUF_path = '/content/datasets/interaction-set/AUF/AUPF190.jpg'

model = torch.hub.load(path_hubconfig, 'custom',
                     path=path_weightfile, source='local',)

jpg_files = []

for filename in os.listdir(Combined_path):
    if filename.endswith(".jpg"):
        # print(filename)
        file_path = os.path.join(Combined_path, filename)
        jpg_files.append(file_path)

# to sort in order of the true value file "Combined csv"
jpg_files.sort()
print(jpg_files)
# print(len(jpg_files))

results_torch = model(jpg_files, size=img_size)
results_torch.print()
# Out:
# YOLOv5 🚀 1cd2751 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# requirements: /content/requirements.txt not found, check failed.
# Fusing layers...
# custom_YOLOv5m summary: 212 layers, 20856975 parameters, 0 gradients
# Adding AutoShape...
# ['/content/datasets/interaction-set/Combined/AFBI001.jpg', '/content/datasets/interaction-set/Combined/AFBI002.jpg', '/content/datasets/interaction-set/Combined/AFBI003.jpg', '/content/datasets/interaction-set/Combined/AFBI004.jpg', '/content/datasets/interaction-set/Combined/AFBI005.jpg', '/content/datasets/interaction-set/Combined/AFBI006.jpg', '/content/datasets/interaction-set/Combined/AFBI008.jpg', '/content/datasets/interaction-set/Combined/AFBI009.jpg', '/content/datasets/interaction-set/Combined/AFBI010.jpg', '/content/datasets/interaction-set/Combined/AFBI011.jpg', '/content/datasets/interaction-set/Combined/AFBI012.jpg', '/content/datasets/interaction-set/Combined/AFBI013.jpg', '/content/datasets/interaction-set/Combined/AFBI014.jpg', '/content/datasets/interaction-set/Combined/AFBI016.jpg', '/content/datasets/interaction-set/Combined/AFBI017.jpg', '/content/datasets/interaction-set/Combined/AFBI018.jpg', '/content/datasets/interaction-set/Combined/AFBI019.jpg', '/content/datasets/interaction-set/Combined/AFBI021.jpg', '/content/datasets/interaction-set/Combined/AFBI022.jpg', '/content/datasets/interaction-set/Combined/AFBI023.jpg', '/content/datasets/interaction-set/Combined/AFBI024.jpg', '/content/datasets/interaction-set/Combined/AFBI025.jpg', '/content/datasets/interaction-set/Combined/AFBI027.jpg', '/content/datasets/interaction-set/Combined/AFBI028.jpg', '/content/datasets/interaction-set/Combined/AFBI029.jpg', '/content/datasets/interaction-set/Combined/AFBI030.jpg', '/content/datasets/interaction-set/Combined/AFBI031.jpg', '/content/datasets/interaction-set/Combined/AFBI033.jpg', '/content/datasets/interaction-set/Combined/AFBI034.jpg', '/content/datasets/interaction-set/Combined/AFBI036.jpg', '/content/datasets/interaction-set/Combined/AFBI039.jpg', '/content/datasets/interaction-set/Combined/AFBI041.jpg', '/content/datasets/interaction-set/Combined/AFBI042.jpg', '/content/datasets/interaction-set/Combined/AFBI043.jpg', '/content/datasets/interaction-set/Combined/AFBI045.jpg', '/content/datasets/interaction-set/Combined/AFBI047.jpg', '/content/datasets/interaction-set/Combined/AFBI048.jpg', '/content/datasets/interaction-set/Combined/AFBI049.jpg', '/content/datasets/interaction-set/Combined/AFBI050.jpg', '/content/datasets/interaction-set/Combined/AFBI051.jpg', '/content/datasets/interaction-set/Combined/AFBI052.jpg', '/content/datasets/interaction-set/Combined/AFBI053.jpg', '/content/datasets/interaction-set/Combined/AFBI054.jpg', '/content/datasets/interaction-set/Combined/AFBI057.jpg', '/content/datasets/interaction-set/Combined/AFBI058.jpg', '/content/datasets/interaction-set/Combined/AFBI059.jpg', '/content/datasets/interaction-set/Combined/AFBI060.jpg', '/content/datasets/interaction-set/Combined/AFBI061.jpg', '/content/datasets/interaction-set/Combined/AFBI062.jpg', '/content/datasets/interaction-set/Combined/AFBI063.jpg', '/content/datasets/interaction-set/Combined/AFBI064.jpg', '/content/datasets/interaction-set/Combined/AFBI065.jpg', '/content/datasets/interaction-set/Combined/AFBI066.jpg', '/content/datasets/interaction-set/Combined/AFBI067.jpg', '/content/datasets/interaction-set/Combined/AFBI068.jpg', '/content/datasets/interaction-set/Combined/AFBI070.jpg', '/content/datasets/interaction-set/Combined/AFBI071.jpg', '/content/datasets/interaction-set/Combined/AFBI072.jpg', '/content/datasets/interaction-set/Combined/AFBI073.jpg', '/content/datasets/interaction-set/Combined/AFBI074.jpg', '/content/datasets/interaction-set/Combined/AFBI075.jpg', '/content/datasets/interaction-set/Combined/AFBI076.jpg', '/content/datasets/interaction-set/Combined/AFBI077.jpg', '/content/datasets/interaction-set/Combined/AFBI078.jpg', '/content/datasets/interaction-set/Combined/AFBI079.jpg', '/content/datasets/interaction-set/Combined/AFBI080.jpg', '/content/datasets/interaction-set/Combined/AFBI081.jpg', '/content/datasets/interaction-set/Combined/AFBI082.jpg', '/content/datasets/interaction-set/Combined/AFBI083.jpg ...
# image 1/738: 411x811 9 Heads, 8 Rears
# image 2/738: 411x811 8 Heads, 8 Rears
# image 3/738: 411x811 8 Heads, 8 Rears
# image 4/738: 411x811 9 Heads, 9 Rears
# image 5/738: 411x811 9 Heads, 8 Rears
# image 6/738: 411x811 8 Heads, 8 Rears
# image 7/738: 411x811 8 Heads, 9 Rears
# image 8/738: 411x811 9 Heads, 7 Rears
# image 9/738: 411x811 10 Heads, 9 Rears
# image 10/738: 411x811 8 Heads, 9 Rears
# image 11/738: 411x811 8 Heads, 9 Rears
# image 12/738: 411x811 9 Heads, 9 Rears
# image 13/738: 411x811 8 Heads, 9 Rears
# image 14/738: 411x811 8 Heads, 8 Rears
# image 15/738: 411x811 7 Heads, 9 Rears
# image 16/738: 411x811 9 Heads, 9 Rears
# image 17/738: 411x811 9 Heads, 9 Rears
# image 18/738: 411x811 9 Heads, 8 Rears
# image 19/738: 411x811 9 Heads, 9 Rears
# image 20/738: 411x811 10 Heads, 12 Rears
# image 21/738: 411x811 10 Heads, 8 Rears
# image 22/738: 411x811 9 Heads, 9 Rears
# image 23/738: 411x811 9 Heads, 9 Rears
# image 24/738: 411x811 9 Heads, 9 Rears
# image 25/738: 411x811 10 Heads, 9 Rears
# image 26/738: 411x811 7 Heads, 9 Rears
# image 27/738: 411x811 8 Heads, 9 Rears
# image 28/738: 411x811 10 Heads, 8 Rears
# image 29/738: 411x811 9 Heads, 9 Rears
# image 30/738: 411x811 8 Heads, 8 Rears
# image 31/738: 411x811 9 Heads, 10 Rears
# image 32/738: 411x811 9 Heads, 9 Rears
# image 33/738: 411x811 10 Heads, 11 Rears
# image 34/738: 411x811 10 Heads, 9 Rears
# image 35/738: 411x811 10 Heads, 10 Rears
# image 36/738: 411x811 9 Heads, 11 Rears
# image 37/738: 411x811 10 Heads, 11 Rears
# image 38/738: 411x811 9 Heads, 10 Rears
# image 39/738: 411x811 10 Heads, 10 Rears
# image 40/738: 411x811 9 Heads, 9 Rears
# image 41/738: 411x811 11 Heads, 9 Rears
# image 42/738: 411x811 10 Heads, 10 Rears
# image 43/738: 411x811 11 Heads, 10 Rears
# image 44/738: 411x811 11 Heads, 10 Rears
# image 45/738: 411x811 12 Heads, 10 Rears
# image 46/738: 411x811 11 Heads, 10 Rears
# image 47/738: 411x811 12 Heads, 11 Rears
# image 48/738: 411x811 10 Heads, 10 Rears
# image 49/738: 411x811 10 Heads, 10 Rears
# image 50/738: 411x811 10 Heads, 10 Rears
# image 51/738: 411x811 9 Heads, 9 Rears
# image 52/738: 411x811 9 Heads, 9 Rears
# image 53/738: 411x811 9 Heads, 9 Rears
# image 54/738: 411x811 9 Heads, 9 Rears
# image 55/738: 411x811 9 Heads, 9 Rears
# image 56/738: 411x811 9 Heads, 7 Rears
# image 57/738: 411x811 10 Heads, 9 Rears
# image 58/738: 411x811 9 Heads, 9 Rears
# image 59/738: 411x811 10 Heads, 9 Rears
# image 60/738: 411x811 10 Heads, 9 Rears
# image 61/738: 411x811 11 Heads, 9 Rears
# image 62/738: 411x811 11 Heads, 10 Rears
# image 63/738: 411x811 11 Heads, 10 Rears
# image 64/738: 411x811 10 Heads, 10 Rears
# image 65/738: 411x811 10 Heads, 10 Rears
# image 66/738: 411x811 10 Heads, 10 Rears
# image 67/738: 411x811 10 Heads, 10 Rears
# image 68/738: 411x811 11 Heads, 10 Rears
# image 69/738: 411x811 10 Heads, 10 Rears
# image 70/738: 411x811 11 Heads, 10 Rears
# image 71/738: 411x811 11 Heads, 10 Rears
# image 72/738: 411x811 10 Heads, 10 Rears
# image 73/738: 411x811 11 Heads, 10 Rears
# image 74/738: 411x811 11 Heads, 10 Rears
# image 75/738: 411x811 11 Heads, 10 Rears
# image 76/738: 411x811 10 Heads, 10 Rears
# image 77/738: 411x811 11 Heads, 10 Rears
# image 78/738: 411x811 10 Heads, 10 Rears
# image 79/738: 411x811 10 Heads, 10 Rears
# image 80/738: 411x811 10 Heads, 10 Rears
# image 81/738: 411x811 11 Heads, 10 Rears
# image 82/738: 424x745 9 Heads, 9 Rears
# image 83/738: 424x745 10 Heads, 9 Rears
# image 84/738: 424x745 10 Heads, 9 Rears
# image 85/738: 424x745 9 Heads, 8 Rears
# image 86/738: 424x745 10 Heads, 8 Rears
# image 87/738: 424x745 10 Heads, 9 Rears
# image 88/738: 424x745 8 Heads, 9 Rears
# image 89/738: 424x745 9 Heads, 9 Rears
# image 90/738: 424x745 9 Heads, 9 Rears
# image 91/738: 424x745 10 Heads, 9 Rears
# image 92/738: 424x745 9 Heads, 10 Rears
# image 93/738: 424x745 8 Heads, 9 Rears
# image 94/738: 424x745 7 Heads, 9 Rears
# image 95/738: 424x745 10 Heads, 9 Rears
# image 96/738: 424x745 9 Heads, 9 Rears
# image 97/738: 424x745 9 Heads, 9 Rears
# image 98/738: 424x745 8 Heads, 9 Rears
# image 99/738: 424x745 7 Heads, 9 Rears
# image 100/738: 424x745 10 Heads, 9 Rears
# image 101/738: 424x745 8 Heads, 9 Rears
# image 102/738: 424x745 9 Heads, 9 Rears
# image 103/738: 424x745 9 Heads, 9 Rears
# image 104/738: 424x745 9 Heads, 9 Rears
# image 105/738: 424x745 9 Heads, 9 Rears
# image 106/738: 424x745 9 Heads, 9 Rears
# image 107/738: 424x745 8 Heads, 9 Rears
# image 108/738: 424x745 9 Heads, 9 Rears
# image 109/738: 424x745 9 Heads, 9 Rears
# image 110/738: 424x745 9 Heads, 8 Rears
# image 111/738: 424x745 9 Heads, 8 Rears
# image 112/738: 424x745 9 Heads, 9 Rears
# image 113/738: 424x745 8 Heads, 9 Rears
# image 114/738: 424x745 8 Heads, 9 Rears
# image 115/738: 424x745 9 Heads, 9 Rears
# image 116/738: 424x745 8 Heads, 8 Rears
# image 117/738: 424x745 9 Heads, 9 Rears
# image 118/738: 424x745 9 Heads, 9 Rears
# image 119/738: 424x745 9 Heads, 9 Rears
# image 120/738: 424x745 8 Heads, 9 Rears
# image 121/738: 424x745 9 Heads, 9 Rears
# image 122/738: 424x745 9 Heads, 9 Rears
# image 123/738: 424x745 9 Heads, 9 Rears
# image 124/738: 424x745 8 Heads, 9 Rears
# image 125/738: 424x745 9 Heads, 9 Rears
# image 126/738: 424x745 9 Heads, 9 Rears
# image 127/738: 424x745 9 Heads, 9 Rears
# image 128/738: 424x745 8 Heads, 9 Rears
# image 129/738: 424x745 7 Heads, 8 Rears
# image 130/738: 424x745 8 Heads, 8 Rears
# image 131/738: 424x745 10 Heads, 9 Rears
# image 132/738: 424x745 9 Heads, 9 Rears
# image 133/738: 424x745 8 Heads, 8 Rears
# image 134/738: 424x745 7 Heads, 8 Rears
# image 135/738: 424x745 9 Heads, 10 Rears
# image 136/738: 424x745 9 Heads, 9 Rears
# image 137/738: 424x745 9 Heads, 9 Rears
# image 138/738: 424x745 9 Heads, 9 Rears
# image 139/738: 424x745 9 Heads, 9 Rears
# image 140/738: 424x745 8 Heads, 10 Rears
# image 141/738: 424x745 9 Heads, 9 Rears
# image 142/738: 424x745 9 Heads, 9 Rears
# image 143/738: 424x745 9 Heads, 9 Rears
# image 144/738: 424x745 9 Heads, 9 Rears
# image 145/738: 424x745 9 Heads, 9 Rears
# image 146/738: 424x745 9 Heads, 9 Rears
# image 147/738: 424x745 9 Heads, 9 Rears
# image 148/738: 424x745 9 Heads, 9 Rears
# image 149/738: 424x745 9 Heads, 9 Rears
# image 150/738: 424x745 9 Heads, 9 Rears
# image 151/738: 424x745 9 Heads, 9 Rears
# image 152/738: 424x745 9 Heads, 9 Rears
# image 153/738: 424x745 9 Heads, 9 Rears
# image 154/738: 424x745 8 Heads, 9 Rears
# image 155/738: 424x745 9 Heads, 9 Rears
# image 156/738: 424x745 9 Heads, 9 Rears
# image 157/738: 424x745 8 Heads, 9 Rears
# image 158/738: 424x745 9 Heads, 9 Rears
# image 159/738: 424x745 9 Heads, 9 Rears
# image 160/738: 424x745 9 Heads, 8 Rears
# image 161/738: 424x745 8 Heads, 9 Rears
# image 162/738: 424x745 7 Heads, 9 Rears
# image 163/738: 424x745 8 Heads, 9 Rears
# image 164/738: 424x745 9 Heads, 9 Rears
# image 165/738: 424x745 10 Heads, 9 Rears
# image 166/738: 424x745 9 Heads, 9 Rears
# image 167/738: 424x745 9 Heads, 9 Rears
# image 168/738: 424x745 9 Heads, 9 Rears
# image 169/738: 424x745 9 Heads, 9 Rears
# image 170/738: 424x745 9 Heads, 9 Rears
# image 171/738: 424x745 9 Heads, 9 Rears
# image 172/738: 424x745 10 Heads, 9 Rears
# image 173/738: 424x745 9 Heads, 9 Rears
# image 174/738: 424x745 9 Heads, 8 Rears
# image 175/738: 424x745 9 Heads, 9 Rears
# image 176/738: 424x745 9 Heads, 9 Rears
# image 177/738: 424x745 9 Heads, 9 Rears
# image 178/738: 424x745 9 Heads, 9 Rears
# image 179/738: 424x745 9 Heads, 9 Rears
# image 180/738: 424x745 9 Heads, 9 Rears
# image 181/738: 424x745 9 Heads, 9 Rears
# image 182/738: 424x745 9 Heads, 9 Rears
# image 183/738: 424x745 9 Heads, 9 Rears
# image 184/738: 424x745 9 Heads, 9 Rears
# image 185/738: 424x745 9 Heads, 9 Rears
# image 186/738: 424x745 9 Heads, 9 Rears
# image 187/738: 424x745 9 Heads, 9 Rears
# image 188/738: 424x745 9 Heads, 8 Rears
# image 189/738: 424x745 9 Heads, 9 Rears
# image 190/738: 424x745 9 Heads, 9 Rears
# image 191/738: 424x745 9 Heads, 9 Rears
# image 192/738: 424x745 9 Heads, 9 Rears
# image 193/738: 424x745 8 Heads, 9 Rears
# image 194/738: 424x745 8 Heads, 9 Rears
# image 195/738: 424x745 8 Heads, 8 Rears
# image 196/738: 424x745 8 Heads, 9 Rears
# image 197/738: 424x745 10 Heads, 9 Rears
# image 198/738: 424x745 10 Heads, 9 Rears
# image 199/738: 424x745 9 Heads, 9 Rears
# image 200/738: 424x745 9 Heads, 9 Rears
# image 201/738: 424x745 8 Heads, 9 Rears
# image 202/738: 424x745 8 Heads, 8 Rears
# image 203/738: 424x745 9 Heads, 9 Rears
# image 204/738: 424x745 8 Heads, 7 Rears
# image 205/738: 424x745 8 Heads, 8 Rears
# image 206/738: 424x745 7 Heads, 8 Rears
# image 207/738: 424x745 9 Heads, 8 Rears
# image 208/738: 424x745 8 Heads, 8 Rears
# image 209/738: 424x745 8 Heads, 8 Rears
# image 210/738: 424x745 7 Heads, 8 Rears
# image 211/738: 424x745 9 Heads, 8 Rears
# image 212/738: 424x745 8 Heads, 8 Rears
# image 213/738: 424x745 7 Heads, 7 Rears
# image 214/738: 424x745 8 Heads, 8 Rears
# image 215/738: 424x745 6 Heads, 8 Rears
# image 216/738: 424x745 8 Heads, 9 Rears
# image 217/738: 424x745 8 Heads, 8 Rears
# image 218/738: 424x745 8 Heads, 7 Rears
# image 219/738: 424x745 9 Heads, 9 Rears
# image 220/738: 424x745 8 Heads, 9 Rears
# image 221/738: 424x745 8 Heads, 8 Rears
# image 222/738: 424x745 8 Heads, 8 Rears
# image 223/738: 424x745 8 Heads, 8 Rears
# image 224/738: 424x745 7 Heads, 9 Rears
# image 225/738: 424x745 8 Heads, 9 Rears
# image 226/738: 424x745 9 Heads, 9 Rears
# image 227/738: 424x745 9 Heads, 10 Rears
# image 228/738: 424x745 9 Heads, 9 Rears
# image 229/738: 424x745 9 Heads, 9 Rears
# image 230/738: 424x745 9 Heads, 9 Rears
# image 231/738: 424x745 9 Heads, 10 Rears
# image 232/738: 424x745 8 Heads, 9 Rears
# image 233/738: 424x745 8 Heads, 8 Rears
# image 234/738: 424x745 8 Heads, 8 Rears
# image 235/738: 424x745 7 Heads, 7 Rears
# image 236/738: 424x745 7 Heads, 8 Rears
# image 237/738: 424x745 7 Heads, 8 Rears
# image 238/738: 424x745 8 Heads, 8 Rears
# image 239/738: 424x745 7 Heads, 8 Rears
# image 240/738: 424x745 7 Heads, 8 Rears
# image 241/738: 424x745 6 Heads, 9 Rears
# image 242/738: 424x745 7 Heads, 8 Rears
# image 243/738: 424x745 7 Heads, 7 Rears
# image 244/738: 424x745 7 Heads, 8 Rears
# image 245/738: 424x745 7 Heads, 8 Rears
# image 246/738: 424x745 7 Heads, 8 Rears
# image 247/738: 424x745 6 Heads, 8 Rears
# image 248/738: 424x745 7 Heads, 8 Rears
# image 249/738: 424x745 7 Heads, 8 Rears
# image 250/738: 424x745 8 Heads, 9 Rears
# image 251/738: 424x745 8 Heads, 8 Rears
# image 252/738: 411x811 9 Heads, 9 Rears
# image 253/738: 411x811 9 Heads, 9 Rears
# image 254/738: 411x811 9 Heads, 9 Rears
# image 255/738: 411x811 9 Heads, 9 Rears
# image 256/738: 411x811 9 Heads, 9 Rears
# image 257/738: 411x811 9 Heads, 11 Rears
# image 258/738: 411x811 9 Heads, 10 Rears
# image 259/738: 411x811 9 Heads, 10 Rears
# image 260/738: 411x811 10 Heads, 10 Rears
# image 261/738: 411x811 10 Heads, 10 Rears
# image 262/738: 411x811 9 Heads, 9 Rears
# image 263/738: 411x811 9 Heads, 10 Rears
# image 264/738: 411x811 10 Heads, 10 Rears
# image 265/738: 411x811 9 Heads, 10 Rears
# image 266/738: 411x811 10 Heads, 11 Rears
# image 267/738: 411x811 8 Heads, 10 Rears
# image 268/738: 411x811 8 Heads, 8 Rears
# image 269/738: 411x811 9 Heads, 9 Rears
# image 270/738: 411x811 8 Heads, 9 Rears
# image 271/738: 411x811 8 Heads, 9 Rears
# image 272/738: 411x811 9 Heads, 9 Rears
# image 273/738: 411x811 9 Heads, 9 Rears
# image 274/738: 411x811 9 Heads, 8 Rears
# image 275/738: 411x811 9 Heads, 8 Rears
# image 276/738: 411x811 9 Heads, 9 Rears
# image 277/738: 411x811 11 Heads, 10 Rears
# image 278/738: 411x811 9 Heads, 9 Rears
# image 279/738: 411x811 7 Heads, 9 Rears
# image 280/738: 411x811 8 Heads, 9 Rears
# image 281/738: 411x811 8 Heads, 9 Rears
# image 282/738: 411x811 8 Heads, 9 Rears
# image 283/738: 411x811 9 Heads, 9 Rears
# image 284/738: 411x811 9 Heads, 9 Rears
# image 285/738: 411x811 8 Heads, 9 Rears
# image 286/738: 411x811 8 Heads, 9 Rears
# image 287/738: 411x811 8 Heads, 9 Rears
# image 288/738: 411x811 8 Heads, 9 Rears
# image 289/738: 411x811 8 Heads, 9 Rears
# image 290/738: 411x811 9 Heads, 8 Rears
# image 291/738: 411x811 9 Heads, 9 Rears
# image 292/738: 411x811 9 Heads, 9 Rears
# image 293/738: 411x811 5 Heads, 9 Rears
# image 294/738: 411x811 8 Heads, 9 Rears
# image 295/738: 411x811 8 Heads, 9 Rears
# image 296/738: 411x811 8 Heads, 9 Rears
# image 297/738: 411x811 6 Heads, 8 Rears
# image 298/738: 411x811 6 Heads, 7 Rears
# image 299/738: 411x811 6 Heads, 9 Rears
# image 300/738: 411x811 10 Heads, 9 Rears
# image 301/738: 411x811 8 Heads, 9 Rears
# image 302/738: 411x811 8 Heads, 9 Rears
# image 303/738: 411x811 8 Heads, 9 Rears
# image 304/738: 411x811 9 Heads, 9 Rears
# image 305/738: 411x811 10 Heads, 9 Rears
# image 306/738: 411x811 8 Heads, 9 Rears
# image 307/738: 411x811 7 Heads, 9 Rears
# image 308/738: 411x811 7 Heads, 9 Rears
# image 309/738: 411x811 6 Heads, 9 Rears
# image 310/738: 411x811 9 Heads, 8 Rears
# image 311/738: 411x811 6 Heads, 9 Rears
# image 312/738: 411x811 6 Heads, 9 Rears
# image 313/738: 411x811 8 Heads, 8 Rears
# image 314/738: 411x811 7 Heads, 9 Rears
# image 315/738: 411x811 9 Heads, 9 Rears
# image 316/738: 411x811 8 Heads, 9 Rears
# image 317/738: 411x811 8 Heads, 9 Rears
# image 318/738: 411x811 8 Heads, 9 Rears
# image 319/738: 411x811 9 Heads, 9 Rears
# image 320/738: 411x811 9 Heads, 8 Rears
# image 321/738: 411x811 9 Heads, 9 Rears
# image 322/738: 411x811 8 Heads, 9 Rears
# image 323/738: 411x811 8 Heads, 9 Rears
# image 324/738: 411x811 8 Heads, 9 Rears
# image 325/738: 411x811 8 Heads, 8 Rears
# image 326/738: 411x811 7 Heads, 9 Rears
# image 327/738: 411x811 9 Heads, 8 Rears
# image 328/738: 411x811 9 Heads, 9 Rears
# image 329/738: 411x811 9 Heads, 9 Rears
# image 330/738: 411x811 9 Heads, 9 Rears
# image 331/738: 411x811 8 Heads, 9 Rears
# image 332/738: 411x811 9 Heads, 9 Rears
# image 333/738: 411x811 8 Heads, 9 Rears
# image 334/738: 411x811 9 Heads, 9 Rears
# image 335/738: 411x811 8 Heads, 9 Rears
# image 336/738: 411x811 8 Heads, 9 Rears
# image 337/738: 411x811 8 Heads, 9 Rears
# image 338/738: 411x811 8 Heads, 9 Rears
# image 339/738: 411x811 8 Heads, 9 Rears
# image 340/738: 411x811 9 Heads, 9 Rears
# image 341/738: 411x811 8 Heads, 8 Rears
# image 342/738: 411x811 8 Heads, 8 Rears
# image 343/738: 411x811 7 Heads, 8 Rears
# image 344/738: 411x811 7 Heads, 7 Rears
# image 345/738: 411x811 8 Heads, 8 Rears
# image 346/738: 411x811 9 Heads, 9 Rears
# image 347/738: 411x811 8 Heads, 8 Rears
# image 348/738: 411x811 8 Heads, 9 Rears
# image 349/738: 411x811 9 Heads, 9 Rears
# image 350/738: 411x811 8 Heads, 9 Rears
# image 351/738: 411x811 8 Heads, 9 Rears
# image 352/738: 411x811 8 Heads, 9 Rears
# image 353/738: 411x811 8 Heads, 9 Rears
# image 354/738: 411x811 8 Heads, 9 Rears
# image 355/738: 411x811 8 Heads, 9 Rears
# image 356/738: 411x811 7 Heads, 9 Rears
# image 357/738: 411x811 7 Heads, 9 Rears
# image 358/738: 411x811 9 Heads, 9 Rears
# image 359/738: 411x811 9 Heads, 9 Rears
# image 360/738: 411x811 8 Heads, 9 Rears
# image 361/738: 411x811 8 Heads, 9 Rears
# image 362/738: 411x811 8 Heads, 9 Rears
# image 363/738: 411x811 7 Heads, 9 Rears
# image 364/738: 411x811 7 Heads, 9 Rears
# image 365/738: 382x698 10 Heads, 9 Rears
# image 366/738: 382x698 8 Heads, 9 Rears
# image 367/738: 382x698 9 Heads, 9 Rears
# image 368/738: 382x698 9 Heads, 9 Rears
# image 369/738: 382x698 9 Heads, 9 Rears
# image 370/738: 382x698 8 Heads, 9 Rears
# image 371/738: 382x698 11 Heads, 10 Rears
# image 372/738: 382x698 9 Heads, 9 Rears
# image 373/738: 382x698 10 Heads, 10 Rears
# image 374/738: 382x698 8 Heads, 9 Rears
# image 375/738: 382x698 9 Heads, 9 Rears
# image 376/738: 382x698 10 Heads, 9 Rears
# image 377/738: 382x698 10 Heads, 10 Rears
# image 378/738: 382x698 8 Heads, 8 Rears
# image 379/738: 382x698 8 Heads, 8 Rears
# image 380/738: 382x698 8 Heads, 8 Rears
# image 381/738: 382x698 9 Heads, 9 Rears
# image 382/738: 382x698 7 Heads, 8 Rears
# image 383/738: 382x698 9 Heads, 10 Rears
# image 384/738: 382x698 9 Heads, 9 Rears
# image 385/738: 355x630 9 Heads, 10 Rears
# image 386/738: 355x630 8 Heads, 7 Rears
# image 387/738: 355x630 8 Heads, 8 Rears
# image 388/738: 355x630 7 Heads, 8 Rears
# image 389/738: 355x630 8 Heads, 8 Rears
# image 390/738: 355x630 8 Heads, 9 Rears
# image 391/738: 355x630 10 Heads, 9 Rears
# image 392/738: 355x630 8 Heads, 8 Rears
# image 393/738: 432x765 8 Heads, 8 Rears
# image 394/738: 432x765 8 Heads, 8 Rears
# image 395/738: 432x765 9 Heads, 9 Rears
# image 396/738: 432x765 7 Heads, 8 Rears
# image 397/738: 432x765 8 Heads, 8 Rears
# image 398/738: 432x765 7 Heads, 8 Rears
# image 399/738: 432x765 8 Heads, 9 Rears
# image 400/738: 432x765 9 Heads, 9 Rears
# image 401/738: 432x765 10 Heads, 10 Rears
# image 402/738: 432x765 9 Heads, 10 Rears
# image 403/738: 432x765 9 Heads, 10 Rears
# image 404/738: 432x765 8 Heads, 8 Rears
# image 405/738: 432x765 8 Heads, 8 Rears
# image 406/738: 379x695 8 Heads, 8 Rears
# image 407/738: 379x695 8 Heads, 8 Rears
# image 408/738: 382x692 10 Heads, 9 Rears
# image 409/738: 382x692 9 Heads, 11 Rears
# image 410/738: 382x692 9 Heads, 8 Rears
# image 411/738: 382x692 9 Heads, 10 Rears
# image 412/738: 382x692 9 Heads, 9 Rears
# image 413/738: 382x692 9 Heads, 9 Rears
# image 414/738: 382x692 9 Heads, 9 Rears
# image 415/738: 382x692 10 Heads, 9 Rears
# image 416/738: 382x692 9 Heads, 10 Rears
# image 417/738: 382x692 10 Heads, 10 Rears
# image 418/738: 382x692 8 Heads, 9 Rears
# image 419/738: 353x668 9 Heads, 9 Rears
# image 420/738: 353x668 9 Heads, 9 Rears
# image 421/738: 353x668 8 Heads, 9 Rears
# image 422/738: 353x668 9 Heads, 9 Rears
# image 423/738: 353x668 10 Heads, 9 Rears
# image 424/738: 353x668 9 Heads, 9 Rears
# image 425/738: 353x668 9 Heads, 9 Rears
# image 426/738: 353x668 9 Heads, 9 Rears
# image 427/738: 398x691 9 Heads, 9 Rears
# image 428/738: 398x691 9 Heads, 9 Rears
# image 429/738: 398x691 9 Heads, 10 Rears
# image 430/738: 398x691 9 Heads, 9 Rears
# image 431/738: 398x691 9 Heads, 9 Rears
# image 432/738: 398x691 9 Heads, 9 Rears
# image 433/738: 398x691 9 Heads, 9 Rears
# image 434/738: 498x733 11 Heads, 11 Rears
# image 435/738: 498x733 11 Heads, 10 Rears
# image 436/738: 498x733 10 Heads, 11 Rears
# image 437/738: 498x733 11 Heads, 9 Rears
# image 438/738: 498x733 9 Heads, 10 Rears
# image 439/738: 498x733 9 Heads, 10 Rears
# image 440/738: 498x733 10 Heads, 10 Rears
# image 441/738: 498x733 10 Heads, 11 Rears
# image 442/738: 498x733 9 Heads, 11 Rears
# image 443/738: 498x733 10 Heads, 11 Rears
# image 444/738: 498x733 9 Heads, 11 Rears
# image 445/738: 498x733 9 Heads, 9 Rears
# image 446/738: 498x733 9 Heads, 9 Rears
# image 447/738: 498x733 9 Heads, 9 Rears
# image 448/738: 489x690 10 Heads, 9 Rears
# image 449/738: 489x690 10 Heads, 8 Rears
# image 450/738: 489x690 11 Heads, 8 Rears
# image 451/738: 489x690 10 Heads, 10 Rears
# image 452/738: 489x690 10 Heads, 9 Rears
# image 453/738: 489x690 9 Heads, 10 Rears
# image 454/738: 489x690 9 Heads, 8 Rears
# image 455/738: 489x690 10 Heads, 9 Rears
# image 456/738: 489x690 9 Heads, 9 Rears
# image 457/738: 489x690 8 Heads, 8 Rears
# image 458/738: 489x690 9 Heads, 8 Rears
# image 459/738: 489x690 8 Heads, 8 Rears
# image 460/738: 489x690 9 Heads, 8 Rears
# image 461/738: 489x690 8 Heads, 9 Rears
# image 462/738: 489x690 5 Heads, 11 Rears
# image 463/738: 457x667 9 Heads, 7 Rears
# image 464/738: 457x667 9 Heads, 6 Rears
# image 465/738: 457x667 9 Heads, 7 Rears
# image 466/738: 457x667 9 Heads, 6 Rears
# image 467/738: 457x667 8 Heads, 6 Rears
# image 468/738: 457x667 9 Heads, 6 Rears
# image 469/738: 457x667 8 Heads, 7 Rears
# image 470/738: 457x667 9 Heads, 8 Rears
# image 471/738: 457x667 8 Heads, 8 Rears
# image 472/738: 457x667 8 Heads, 9 Rears
# image 473/738: 457x667 8 Heads, 9 Rears
# image 474/738: 457x667 8 Heads, 9 Rears
# image 475/738: 457x667 9 Heads, 8 Rears
# image 476/738: 457x667 9 Heads, 8 Rears
# image 477/738: 457x667 9 Heads, 8 Rears
# image 478/738: 427x678 6 Heads, 7 Rears
# image 479/738: 427x678 5 Heads, 7 Rears
# image 480/738: 427x678 6 Heads, 6 Rears
# image 481/738: 427x678 6 Heads, 7 Rears
# image 482/738: 427x678 7 Heads, 8 Rears
# image 483/738: 427x678 8 Heads, 7 Rears
# image 484/738: 427x678 7 Heads, 7 Rears
# image 485/738: 427x678 4 Heads, 5 Rears
# image 486/738: 427x678 5 Heads, 6 Rears
# image 487/738: 427x678 4 Heads, 6 Rears
# image 488/738: 427x678 4 Heads, 5 Rears
# image 489/738: 427x678 4 Heads, 5 Rears
# image 490/738: 427x678 6 Heads, 7 Rears
# image 491/738: 427x678 4 Heads, 7 Rears
# image 492/738: 427x678 4 Heads, 7 Rears
# image 493/738: 427x678 5 Heads, 6 Rears
# image 494/738: 427x678 3 Heads, 6 Rears
# image 495/738: 462x756 19 Heads, 18 Rears
# image 496/738: 462x756 17 Heads, 18 Rears
# image 497/738: 462x756 15 Heads, 18 Rears
# image 498/738: 464x738 18 Heads, 16 Rears
# image 499/738: 464x738 16 Heads, 15 Rears
# image 500/738: 464x738 17 Heads, 15 Rears
# image 501/738: 452x736 12 Heads, 15 Rears
# image 502/738: 452x736 14 Heads, 14 Rears
# image 503/738: 452x736 14 Heads, 16 Rears
# image 504/738: 452x736 14 Heads, 16 Rears
# image 505/738: 452x736 14 Heads, 16 Rears
# image 506/738: 452x736 13 Heads, 15 Rears
# image 507/738: 452x736 13 Heads, 15 Rears
# image 508/738: 452x736 13 Heads, 17 Rears
# image 509/738: 452x736 14 Heads, 15 Rears
# image 510/738: 452x736 12 Heads, 15 Rears
# image 511/738: 452x736 12 Heads, 17 Rears
# image 512/738: 452x736 13 Heads, 17 Rears
# image 513/738: 452x736 14 Heads, 16 Rears
# image 514/738: 452x736 13 Heads, 15 Rears
# image 515/738: 460x750 16 Heads, 15 Rears
# image 516/738: 460x750 13 Heads, 15 Rears
# image 517/738: 460x750 13 Heads, 18 Rears
# image 518/738: 460x750 13 Heads, 16 Rears
# image 519/738: 460x750 13 Heads, 16 Rears
# image 520/738: 460x750 16 Heads, 17 Rears
# image 521/738: 460x750 17 Heads, 17 Rears
# image 522/738: 460x750 16 Heads, 18 Rears
# image 523/738: 460x750 19 Heads, 16 Rears
# image 524/738: 476x731 10 Heads, 10 Rears
# image 525/738: 476x731 10 Heads, 10 Rears
# image 526/738: 476x731 10 Heads, 10 Rears
# image 527/738: 476x731 9 Heads, 10 Rears
# image 528/738: 476x731 11 Heads, 10 Rears
# image 529/738: 476x731 11 Heads, 10 Rears
# image 530/738: 476x731 11 Heads, 11 Rears
# image 531/738: 476x731 11 Heads, 11 Rears
# image 532/738: 476x731 12 Heads, 11 Rears
# image 533/738: 476x731 9 Heads, 10 Rears
# image 534/738: 476x731 9 Heads, 11 Rears
# image 535/738: 476x731 9 Heads, 11 Rears
# image 536/738: 476x731 10 Heads, 11 Rears
# image 537/738: 476x731 9 Heads, 10 Rears
# image 538/738: 476x731 9 Heads, 11 Rears
# image 539/738: 460x730 10 Heads, 10 Rears
# image 540/738: 460x730 8 Heads, 10 Rears
# image 541/738: 460x730 8 Heads, 10 Rears
# image 542/738: 460x730 8 Heads, 10 Rears
# image 543/738: 459x734 10 Heads, 10 Rears
# image 544/738: 459x734 10 Heads, 10 Rears
# image 545/738: 459x734 11 Heads, 10 Rears
# image 546/738: 459x734 8 Heads, 11 Rears
# image 547/738: 459x734 9 Heads, 10 Rears
# image 548/738: 459x734 10 Heads, 10 Rears
# image 549/738: 459x734 9 Heads, 11 Rears
# image 550/738: 459x734 9 Heads, 11 Rears
# image 551/738: 459x734 9 Heads, 10 Rears
# image 552/738: 459x734 10 Heads, 10 Rears
# image 553/738: 459x734 8 Heads, 10 Rears
# image 554/738: 459x734 7 Heads, 10 Rears
# image 555/738: 459x734 8 Heads, 10 Rears
# image 556/738: 459x734 8 Heads, 11 Rears
# image 557/738: 459x734 8 Heads, 11 Rears
# image 558/738: 447x709 15 Heads, 15 Rears
# image 559/738: 447x709 13 Heads, 17 Rears
# image 560/738: 447x709 16 Heads, 16 Rears
# image 561/738: 447x709 16 Heads, 16 Rears
# image 562/738: 447x709 15 Heads, 15 Rears
# image 563/738: 447x709 16 Heads, 14 Rears
# image 564/738: 447x709 14 Heads, 14 Rears
# image 565/738: 447x709 15 Heads, 15 Rears
# image 566/738: 443x676 7 Heads, 9 Rears
# image 567/738: 443x676 7 Heads, 8 Rears
# image 568/738: 443x676 7 Heads, 8 Rears
# image 569/738: 443x676 8 Heads, 9 Rears
# image 570/738: 443x676 8 Heads, 8 Rears
# image 571/738: 443x676 8 Heads, 8 Rears
# image 572/738: 443x676 8 Heads, 8 Rears
# image 573/738: 443x676 8 Heads, 8 Rears
# image 574/738: 443x676 8 Heads, 9 Rears
# image 575/738: 443x676 9 Heads, 7 Rears
# image 576/738: 443x676 9 Heads, 7 Rears
# image 577/738: 443x676 11 Heads, 8 Rears
# image 578/738: 443x676 9 Heads, 7 Rears
# image 579/738: 443x676 8 Heads, 7 Rears
# image 580/738: 443x676 8 Heads, 8 Rears
# image 581/738: 443x676 8 Heads, 7 Rears
# image 582/738: 443x676 8 Heads, 6 Rears
# image 583/738: 458x671 13 Heads, 17 Rears
# image 584/738: 458x671 13 Heads, 16 Rears
# image 585/738: 458x671 13 Heads, 17 Rears
# image 586/738: 458x671 15 Heads, 17 Rears
# image 587/738: 458x671 16 Heads, 18 Rears
# image 588/738: 458x671 15 Heads, 19 Rears
# image 589/738: 458x671 16 Heads, 16 Rears
# image 590/738: 458x671 15 Heads, 18 Rears
# image 591/738: 454x738 13 Heads, 16 Rears
# image 592/738: 454x738 12 Heads, 17 Rears
# image 593/738: 454x738 13 Heads, 17 Rears
# image 594/738: 454x738 12 Heads, 17 Rears
# image 595/738: 454x738 13 Heads, 17 Rears
# image 596/738: 454x738 16 Heads, 17 Rears
# image 597/738: 454x738 15 Heads, 17 Rears
# image 598/738: 454x738 15 Heads, 17 Rears
# image 599/738: 454x738 15 Heads, 17 Rears
# image 600/738: 454x738 16 Heads, 16 Rears
# image 601/738: 454x738 15 Heads, 17 Rears
# image 602/738: 454x738 15 Heads, 17 Rears
# image 603/738: 454x738 15 Heads, 18 Rears
# image 604/738: 485x739 15 Heads, 19 Rears
# image 605/738: 485x739 15 Heads, 20 Rears
# image 606/738: 485x739 17 Heads, 19 Rears
# image 607/738: 485x739 15 Heads, 18 Rears
# image 608/738: 485x739 14 Heads, 18 Rears
# image 609/738: 485x739 15 Heads, 17 Rears
# image 610/738: 485x739 16 Heads, 19 Rears
# image 611/738: 485x739 17 Heads, 17 Rears
# image 612/738: 485x739 18 Heads, 16 Rears
# image 613/738: 485x739 16 Heads, 17 Rears
# image 614/738: 485x739 15 Heads, 20 Rears
# image 615/738: 485x739 15 Heads, 17 Rears
# image 616/738: 485x739 14 Heads, 18 Rears
# image 617/738: 482x693 9 Heads, 8 Rears
# image 618/738: 482x693 10 Heads, 9 Rears
# image 619/738: 482x693 10 Heads, 9 Rears
# image 620/738: 482x693 10 Heads, 9 Rears
# image 621/738: 482x693 9 Heads, 8 Rears
# image 622/738: 482x693 7 Heads, 8 Rears
# image 623/738: 482x693 9 Heads, 11 Rears
# image 624/738: 482x693 9 Heads, 8 Rears
# image 625/738: 482x693 9 Heads, 8 Rears
# image 626/738: 482x693 9 Heads, 8 Rears
# image 627/738: 482x693 10 Heads, 10 Rears
# image 628/738: 482x693 10 Heads, 8 Rears
# image 629/738: 482x693 9 Heads, 9 Rears
# image 630/738: 482x693 8 Heads, 10 Rears
# image 631/738: 482x693 6 Heads, 9 Rears
# image 632/738: 482x693 6 Heads, 9 Rears
# image 633/738: 482x693 9 Heads, 10 Rears
# image 634/738: 482x693 9 Heads, 10 Rears
# image 635/738: 482x693 8 Heads, 9 Rears
# image 636/738: 482x693 8 Heads, 10 Rears
# image 637/738: 482x693 10 Heads, 9 Rears
# image 638/738: 482x693 11 Heads, 9 Rears
# image 639/738: 482x693 10 Heads, 9 Rears
# image 640/738: 482x693 10 Heads, 9 Rears
# image 641/738: 482x693 10 Heads, 9 Rears
# image 642/738: 482x693 11 Heads, 10 Rears
# image 643/738: 482x693 8 Heads, 8 Rears
# image 644/738: 482x693 9 Heads, 8 Rears
# image 645/738: 482x693 9 Heads, 8 Rears
# image 646/738: 482x693 10 Heads, 7 Rears
# image 647/738: 482x693 10 Heads, 8 Rears
# image 648/738: 482x693 8 Heads, 9 Rears
# image 649/738: 482x693 7 Heads, 9 Rears
# image 650/738: 509x695 11 Heads, 10 Rears
# image 651/738: 509x695 10 Heads, 11 Rears
# image 652/738: 509x695 10 Heads, 11 Rears
# image 653/738: 509x695 10 Heads, 10 Rears
# image 654/738: 509x695 10 Heads, 11 Rears
# image 655/738: 482x693 7 Heads, 10 Rears
# image 656/738: 509x695 11 Heads, 10 Rears
# image 657/738: 509x695 10 Heads, 11 Rears
# image 658/738: 509x695 10 Heads, 11 Rears
# image 659/738: 509x695 11 Heads, 11 Rears
# image 660/738: 509x695 9 Heads, 11 Rears
# image 661/738: 509x695 11 Heads, 11 Rears
# image 662/738: 509x695 10 Heads, 11 Rears
# image 663/738: 509x695 10 Heads, 12 Rears
# image 664/738: 509x695 11 Heads, 11 Rears
# image 665/738: 509x695 11 Heads, 11 Rears
# image 666/738: 509x695 10 Heads, 10 Rears
# image 667/738: 482x693 8 Heads, 9 Rears
# image 668/738: 482x693 5 Heads, 9 Rears
# image 669/738: 482x693 8 Heads, 7 Rears
# image 670/738: 482x693 8 Heads, 9 Rears
# image 671/738: 509x695 11 Heads, 11 Rears
# image 672/738: 509x695 10 Heads, 12 Rears
# image 673/738: 509x695 11 Heads, 11 Rears
# image 674/738: 509x695 11 Heads, 11 Rears
# image 675/738: 509x695 10 Heads, 9 Rears
# image 676/738: 509x695 11 Heads, 11 Rears
# image 677/738: 509x695 11 Heads, 11 Rears
# image 678/738: 509x695 11 Heads, 11 Rears
# image 679/738: 509x695 10 Heads, 11 Rears
# image 680/738: 509x695 10 Heads, 11 Rears
# image 681/738: 482x693 10 Heads, 9 Rears
# image 682/738: 482x693 10 Heads, 10 Rears
# image 683/738: 482x693 9 Heads, 9 Rears
# image 684/738: 509x736 9 Heads, 9 Rears
# image 685/738: 509x736 8 Heads, 9 Rears
# image 686/738: 509x736 7 Heads, 7 Rears
# image 687/738: 509x736 9 Heads, 11 Rears
# image 688/738: 509x736 10 Heads, 11 Rears
# image 689/738: 509x736 10 Heads, 10 Rears
# image 690/738: 509x736 12 Heads, 10 Rears
# image 691/738: 474x689 10 Heads, 9 Rears
# image 692/738: 474x689 10 Heads, 8 Rears
# image 693/738: 474x689 10 Heads, 11 Rears
# image 694/738: 474x689 11 Heads, 11 Rears
# image 695/738: 474x689 10 Heads, 9 Rears
# image 696/738: 474x689 10 Heads, 8 Rears
# image 697/738: 474x689 9 Heads, 10 Rears
# image 698/738: 474x689 9 Heads, 9 Rears
# image 699/738: 474x689 9 Heads, 10 Rears
# image 700/738: 509x736 8 Heads, 9 Rears
# image 701/738: 509x736 8 Heads, 8 Rears
# image 702/738: 509x736 9 Heads, 10 Rears
# image 703/738: 509x736 9 Heads, 9 Rears
# image 704/738: 474x689 10 Heads, 10 Rears
# image 705/738: 474x689 10 Heads, 9 Rears
# image 706/738: 474x689 11 Heads, 9 Rears
# image 707/738: 474x689 9 Heads, 9 Rears
# image 708/738: 509x736 10 Heads, 10 Rears
# image 709/738: 509x736 11 Heads, 12 Rears
# image 710/738: 474x689 10 Heads, 8 Rears
# image 711/738: 474x689 11 Heads, 11 Rears
# image 712/738: 474x689 11 Heads, 10 Rears
# image 713/738: 474x689 11 Heads, 9 Rears
# image 714/738: 474x689 11 Heads, 10 Rears
# image 715/738: 474x689 10 Heads, 10 Rears
# image 716/738: 474x689 10 Heads, 8 Rears
# image 717/738: 509x736 12 Heads, 11 Rears
# image 718/738: 509x736 10 Heads, 12 Rears
# image 719/738: 509x736 11 Heads, 11 Rears
# image 720/738: 509x736 9 Heads, 10 Rears
# image 721/738: 509x736 10 Heads, 11 Rears
# image 722/738: 509x736 9 Heads, 10 Rears
# image 723/738: 509x736 9 Heads, 7 Rears
# image 724/738: 509x736 9 Heads, 7 Rears
# image 725/738: 474x689 10 Heads, 10 Rears
# image 726/738: 474x689 9 Heads, 10 Rears
# image 727/738: 474x689 11 Heads, 9 Rears
# image 728/738: 474x689 11 Heads, 10 Rears
# image 729/738: 474x689 9 Heads, 8 Rears
# image 730/738: 474x689 11 Heads, 10 Rears
# image 731/738: 474x689 9 Heads, 11 Rears
# image 732/738: 474x689 10 Heads, 9 Rears
# image 733/738: 474x689 8 Heads, 8 Rears
# image 734/738: 474x689 10 Heads, 9 Rears
# image 735/738: 474x689 9 Heads, 9 Rears
# image 736/738: 474x689 8 Heads, 8 Rears
# image 737/738: 474x689 9 Heads, 9 Rears
# image 738/738: 474x689 9 Heads, 8 Rears
# Speed: 7.3ms pre-process, 7.2ms inference, 1.0ms NMS per image at shape (738, 3, 384, 512)

# %%
# sample df of bounding-box csv
# %cd /content/YOLOv5-Modification
import pandas as pd

df = pd.read_csv('test.csv')
df

# %% [markdown]
# **This is the Interaction Method (detect.py)**

# %%
# %cd /content/YOLOv5-Modification
import pandas as pd
import os

df = pd.read_csv('bounding-boxes.csv')

# variables
iou_threshold = 0.05

# df results
results_df = pd.DataFrame(columns=['Image_Name', 'Classification', 'Interaction_Count'])

def compute_interactions(data, threshold, results):
    # unique image names
    image_names = data['Image_Name'].unique()

    # loop for each unique name
    for name in image_names:
      # interaction variables
      interaction_flag = False
      interaction_count = 0

      # subset dataframe with this image name
      name_df = data[data['Image_Name'] == name]

      # subset dataframes of heads and rears
      head_df = name_df[name_df['Object_Name'] == 'Head'].reset_index(drop=True)
      rear_df = name_df[name_df['Object_Name'] == 'Rear'].reset_index(drop=True)

      # loop over heads and rears in the image
      for i, head_row in head_df.iterrows():
        for j, rear_row in rear_df.iterrows():
            # bounding box indexing
            # df[4] = minX, df[5] = maxX, df[6] = minY, df[7] = maxY

            head_minX = head_df.iloc[i, 4]
            head_maxX = head_df.iloc[i, 5]
            head_minY = head_df.iloc[i, 6]
            head_maxY = head_df.iloc[i, 7]

            rear_minX = rear_df.iloc[j, 4]
            rear_maxX = rear_df.iloc[j, 5]
            rear_minY = rear_df.iloc[j, 6]
            rear_maxY = rear_df.iloc[j, 7]

            # this is for the headBox and rearBox
            curr_iou = compute_iou(head_minX, head_maxX, head_minY, head_maxY,
                        rear_minX, rear_maxX, rear_minY, rear_maxY)
            
            # print("computed the IoU:", curr_iou)

            if (curr_iou >= threshold):
              interaction_flag = True
              interaction_count += 1

            # # tester
            # print(i, j)
            # print(head_minX, head_minY, head_maxX, head_maxY)
            # print(rear_minX, rear_minY, rear_maxX, rear_maxY)

      temp_list = [name, 
                   1 if interaction_flag else 0, 
                   interaction_count]
      results.loc[len(results)] = temp_list
    return results

def compute_iou(head_minX, head_maxX, head_minY, head_maxY, rear_minX, rear_maxX, rear_minY, rear_maxY):
    # determine (x,y) coordinates of the intersection rectangle
    x_left = max(head_minX, rear_minX)
    y_top = max(head_minY, rear_minY)
    x_right = min(head_maxX, rear_maxX)
    y_bottom = min(head_maxY, rear_maxY)

    # compute the area of intersection rectangle
    intersection_area = max(0, x_right - x_left + 1) * max(0, y_bottom - y_top + 1)

    # compute area of both prediction and ground-truth
    # rectangles
    headArea = (head_maxX - head_minX + 1) * (head_maxY - head_minY + 1)
    rearArea = (rear_maxX - rear_minX + 1) * (rear_maxY - rear_minY + 1)
    union_area = float(headArea + rearArea - intersection_area)

    # compute IoU
    iou = intersection_area / union_area
    return iou

res = compute_interactions(df, iou_threshold, results_df).copy()
if os.path.exists('results.csv'):
    os.remove('results.csv')
res.to_csv('results.csv', index=False)

# print(res)
# Out:
# /content/YOLOv5-Modification

# %% [markdown]
# **This is Interaction Method (PyTorch)**

# %%
# %cd /content/YOLOv5-Modification
import pandas as pd
import os

# df format [xmin ymin xmax ymax confidence class name], xyxy index is the name
bb = results_torch.pandas().xyxy

# variables
iou_threshold = 0.05

# df results
results_df = pd.DataFrame(columns=['Classification', 'Interaction_Count'])

def compute_interactions(data, threshold, results):
    # loop for each unique name/ image
    for image in bb:
      # interaction variables
      interaction_flag = False
      interaction_count = 0

      # subset dataframe with this image name
      name_df = image

      # subset dataframes of heads and rears
      head_df = name_df[name_df['name'] == 'Head'].reset_index(drop=True)
      rear_df = name_df[name_df['name'] == 'Rear'].reset_index(drop=True)

      # loop over heads and rears in the image
      for i, head_row in head_df.iterrows():
        for j, rear_row in rear_df.iterrows():
            # bounding box indexing
            # df[0] = minX, df[1] = minY, df[2] = maxX, df[3] = maxY

            head_minX = head_df.iloc[i, 0]
            head_minY = head_df.iloc[i, 1]
            head_maxX = head_df.iloc[i, 2]
            head_maxY = head_df.iloc[i, 3]

            rear_minX = rear_df.iloc[j, 0]
            rear_minY = rear_df.iloc[j, 1]
            rear_maxX = rear_df.iloc[j, 2]
            rear_maxY = rear_df.iloc[j, 3]

            # this is for the headBox and rearBox
            curr_iou = compute_iou(head_minX, head_maxX, head_minY, head_maxY,
                        rear_minX, rear_maxX, rear_minY, rear_maxY)
            
            # print("computed the IoU:", curr_iou)

            if (curr_iou >= threshold):
              interaction_flag = True
              interaction_count += 1

            # # tester
            # print(i, j)
            # print(head_minX, head_minY, head_maxX, head_maxY)
            # print(rear_minX, rear_minY, rear_maxX, rear_maxY)

      temp_list = [1 if interaction_flag else 0, 
                   interaction_count]
      results.loc[len(results)] = temp_list
    return results

def compute_iou(head_minX, head_maxX, head_minY, head_maxY, rear_minX, rear_maxX, rear_minY, rear_maxY):
    # determine (x,y) coordinates of the intersection rectangle
    x_left = max(head_minX, rear_minX)
    y_top = max(head_minY, rear_minY)
    x_right = min(head_maxX, rear_maxX)
    y_bottom = min(head_maxY, rear_maxY)

    # compute the area of intersection rectangle
    intersection_area = max(0, x_right - x_left + 1) * max(0, y_bottom - y_top + 1)

    # compute area of both prediction and ground-truth
    # rectangles
    headArea = (head_maxX - head_minX + 1) * (head_maxY - head_minY + 1)
    rearArea = (rear_maxX - rear_minX + 1) * (rear_maxY - rear_minY + 1)
    union_area = float(headArea + rearArea - intersection_area)

    # compute IoU
    iou = intersection_area / union_area
    return iou

res = compute_interactions(bb, iou_threshold, results_df).copy()
if os.path.exists('results.csv'):
    os.remove('results.csv')
res.to_csv('results.csv', index=False)

# print(res)
# Out:
# /content/YOLOv5-Modification

# %% [markdown]
# ## Evaluations

# %% [markdown]
# **Getting and Processing Necessary Data**

# %%
# if os.path.exists(Combined_csv_path):
#     os.remove(Combined_csv_path)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# True Values
truth_df = pd.read_csv(Combined_csv_path)
# Changing column names, removing extra \', binarizing the classification
binarize = lambda x: 0 if x == 0 else 1

truth_df['Image_Name'] = truth_df['Image_Name'].str.replace('\'', '')
truth_df['Classification'] = truth_df['Classification'].apply(binarize)

# truth_df

# %%
# Getting truth_df counts
truth_df['is_AFBI'] = truth_df['Image_Name'].str.contains('AFBI').astype(int)
truth_df['is_AUF'] = truth_df['Image_Name'].str.contains('AUPF').astype(int)
AFBI_grouped = truth_df.groupby('is_AFBI')
# AUF_grouped = truth_df.groupby('is_AUF')

# This creates separated dfs for the two data sets
for name, group in AFBI_grouped:
    df_name = 'AFBI_group_df' if name else 'AUF_group_df'
    globals()[df_name] = group.copy()

truth = truth_df['Classification'].value_counts()
afbi = AFBI_group_df['Classification'].value_counts()
auf = AUF_group_df['Classification'].value_counts()
print("truth:\n", truth,'\n',"afbi:\n",afbi,'\n'," auf:\n",auf,'\n')
# Out:
# truth:
#  0    456
# 1    282
# Name: Classification, dtype: int64
#  afbi:
#  0    322
# 1    111
# Name: Classification, dtype: int64
#   auf:
#  1    171
# 0    134
# Name: Classification, dtype: int64

# %%
# Predicted Values
pred_df = pd.read_csv('results.csv')
# pred_df

# %%
# Getting pred_df counts
# pred_df['is_AFBI'] = pred_df['Image_Name'].str.contains('AFBI').astype(int)
# pred_df['is_AUF'] = pred_df['Image_Name'].str.contains('AUPF').astype(int)
# AFBI_grouped = pred_df.groupby('is_AFBI')

# AUF_grouped = truth_df.groupby('is_AUF')

# This creates separated dfs for the two data sets
# for name, group in AFBI_grouped:
#     df_name = 'AFBI_group_df' if name else 'AUF_group_df'
#     globals()[df_name] = group.copy()

pred = pred_df['Classification'].value_counts()
# afbi = AFBI_group_df['Classification'].value_counts()
# auf = AUF_group_df['Classification'].value_counts()
# print("pred:\n", pred,'\n',"afbi:\n",afbi,'\n'," auf:\n",auf,'\n')
print("pred:\n", pred)
# Out:
# pred:
#  1    380
# 0    358
# Name: Classification, dtype: int64

# %% [markdown]
# **Evaluation Proper**

# %%
print(truth_df.shape[0],
      pred_df.shape[0])
# Out:
# 738 738

# %%
y_true = truth_df["Classification"]
y_pred = pred_df["Classification"]

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, matthews_corrcoef

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
confusion_matrix = confusion_matrix(y_true, y_pred)
mcc = matthews_corrcoef(y_true, y_pred)
n_mcc = (mcc + 1)/2   # normalize to set in range [0,1]
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("nMCC:", n_mcc)
print("Confusion Matrix:\n", confusion_matrix)
# Out:
# Accuracy: 0.7533875338753387
# Precision: 0.631578947368421
# Recall: 0.851063829787234
# F1 Score: 0.7250755287009063
# nMCC: 0.7644718895000668
# Confusion Matrix:
#  [[316 140]
#  [ 42 240]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.clf()

# assume y_true and y_pred are the true and predicted labels
cm = confusion_matrix(y_true, y_pred)

# create a heatmap using seaborn
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d")

# add axis labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

# show the plot
plt.show()
plt.savefig(f"conf_mat_{img_size}_{iou_threshold}.png")

# %%
from google.colab import files
files.download(f'/content/YOLOv5-Modification/conf_mat_{img_size}_{iou_threshold}.png')
